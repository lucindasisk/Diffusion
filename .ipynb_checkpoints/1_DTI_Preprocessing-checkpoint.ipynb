# %%
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber 
from nipype.interfaces.utility import IdentityInterface, Function    
from nipype.pipeline.engine import Node, Workflow, JoinNode, MapNode
from nipype.interfaces import fsl
from nipype.interfaces import brainsuite
from shutil import copyfile
from pandas import Series, read_csv, to_numeric
from glob import glob
from os.path import abspath, expanduser, join
from os import chdir, remove, getcwd
from nipype import config, logging
from datetime import date
today = str(date.today())
config.enable_debug_mode()
# Out:
# /usr/local/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#Set variables
subject_list = ['001-prac']

user = expanduser('~')
home = join(user,'Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data')
if user == '/Users/lucindasisk':
    workflow_dir = join(home, 'workflow_LS')
    data_dir = join(home, 'DataDir_LS')
elif user == '/Users/myelin':
    workflow_dir = join(home, 'workflow')
    data_dir = join(home, 'DataDir')

i = read_csv(join(home, 'index.txt'), sep = ' ', header=None, dtype='Int64')
il = i.loc[0]
index = il.tolist()

# %%
#Setup Datasink, Infosource, Selectfiles

datasink = Node(DataSink(base_directory = data_dir),
                   name='datasink')

#Set infosource iterables
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

#SelectFiles
template = dict(t1 = join(home,'{subject_id}/125-skullstripped_anat.nii.gz'),
                pe1= join(home, '{subject_id}/dti_pe1.nii.gz'),
                pe0= join(home, '{subject_id}/dti_pe0.nii.gz'),
                bvalpe1 = join(home,'{subject_id}/dti_pe1.bval'),
                bvalpe0 = join(home,'{subject_id}/dti_pe0.bval'),
                bvecpe1 = join(home,'{subject_id}/dti_pe1.bvec'),
                bvecpe0 = join(home,'{subject_id}/dti_pe0.bvec'),
                index = join(home, 'index.txt'),
                aps = join(home, 'acqparams.txt'),
                tryxfm = join(home, 'transform.txt'))

sf = Node(SelectFiles(template, 
                      base_directory = home),
          name = 'sf')

# %%
#Create ROIs from b0 volumes for pe1 and pe0, then merge
def create_merged_files(pe1, pe0):
    from nipype.interfaces import fsl
    from os.path import abspath
    fslroi1 = fsl.ExtractROI(in_file = pe1, t_min = 0, t_size = 1, roi_file = 'pe1_1vol.nii.gz').run()  
    fslroi2 = fsl.ExtractROI(in_file = pe0, t_min = 0, t_size = 1, roi_file = 'pe0_1vol.nii.gz').run()  
    merge = fsl.Merge(in_files = ['pe1_1vol.nii.gz', 'pe0_1vol.nii.gz'], 
                      dimension = 't', merged_file = 'pe1_pe0_merged.nii.gz').run()
    merged_file = abspath('pe1_pe0_merged.nii.gz')
    return merged_file

create_merge = Node(Function(input_names=['pe1', 'pe0'],
                             output_names=['merged_file'],
                             function = create_merged_files),
                    name='create_merge')

# %%
#Run topup on merged files from pe1 and pe0
topup = Node(fsl.TOPUP(config = 'b02b0.cnf'),
            name = 'topup',
            out_corrected = 'pe1_pe0_topup.nii.gz')

#Select b0 image for registration
fslroi = Node(fsl.ExtractROI(t_min = 0, 
                             t_size = 1, 
                             roi_file = 'b0_img.nii.gz'),
              name = 'fslroi')

#Reorient topup b0 image to std
reorient1 = Node(fsl.Reorient2Std(out_file = 'pe1_pe0_topup_reorient.nii.gz', 
                                  output_type = 'NIFTI_GZ'),
                    name = 'reorient1')

#Register b0 to T1
register = Node(fsl.FLIRT(out_file = 'pe1_pe0_topup_reorient_reg.nii.gz',
                          out_matrix_file = 'pe1_pe0_topup_reorient_reg.mat',
                          output_type = 'NIFTI_GZ'),
                    name = 'register')

#apply topup from merged file to rest of pe0 scan
apptop = Node(fsl.ApplyTOPUP(out_corrected = 'pe0_applied_topup.nii.gz',
                            method='jac',
                            in_index=[2]),
             name = 'apptop')

#Skullstrip the T1w image
stripT1 = Node(fsl.BET(mask = True,
                       mask_file = 'T1_stripped_mask.nii.gz',
                       out_file = 'T1_stripped_anat.nii.gz'),
              name = 'stripT1')

#Reorient DTI data to standard orientation
reorient = Node(fsl.Reorient2Std(out_file = 'pe0_applied_topup_reoriented.nii.gz',
                              output_type = 'NIFTI_GZ'),
                    name = 'reorient')

#Flirt node to resample DTI data to same dimensions as T1
resample = Node(fsl.FLIRT(out_file = 'pe0_applied_topup_reoriented_resampled.nii.gz',
                          output_type = 'NIFTI_GZ',
                          apply_xfm=True),
                    name = 'resample')

#FSL Eddy correction to remove eddy current distortion
eddy = Node(fsl.Eddy(),
           name = 'eddy')

# %%
preproc_flow = Workflow(name = 'preproc_flow')
preproc_flow.connect([(infosource, sf, [('subject_id','subject_id')]),
                      (sf, create_merge, [('pe1', 'pe1'),
                                          ('pe0','pe0')]),
                      (create_merge, datasink, [('merged_file', '1_Check_Unwarped')]),
                      (create_merge, topup, [('merged_file', 'in_file')]),
                      (sf, topup, [('aps','encoding_file')]),
                      (topup, datasink,[('out_corrected', '1_Check_Unwarped.@par')]),
                      (topup, fslroi, [('out_corrected', 'in_file')]),
                      (fslroi, reorient1, [('roi_file', 'in_file')]),
                      (sf, register, [('t1', 'reference')]),
                      (reorient1, register, [('out_file', 'in_file')]),
                      (register, datasink, [('out_file', '1_Check_Unwarped.@par.@par')]),
                      (topup, apptop, [('out_fieldcoef', 'in_topup_fieldcoef'),
                                       ('out_movpar', 'in_topup_movpar')]),
                      (sf, apptop, [('pe0', 'in_files'),
                                    ('aps', 'encoding_file')]),
                      (apptop, datasink, [('out_corrected', '1_Check_Unwarped.@par.@par.@par')]),
                      (sf, stripT1, [('t1', 'in_file')]),
                      (stripT1, datasink, [('out_file', '1_Check_Unwarped.@par.@par.@par.@par'),
                                           ('mask_file', '1_Check_Unwarped.@par.@par.@par.@par.@par')]),
                      (apptop, reorient, [('out_corrected','in_file')]),
                      (reorient, datasink, [('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par')]),
                      (reorient, resample, [('out_file','in_file')]),
                      (sf, resample, [('t1','reference')]),
                      (register, resample, [('out_matrix_file', 'in_matrix_file')]),
                      (resample, datasink, [('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par.@par')])   
#                       (sf, eddy, [('index', 'in_index'),
#                                  ('bvecpe0', 'in_bvec'),
#                                  ('bvalpe0', 'in_bval'),
#                                  ('aps', 'in_acqp')]),
#                       (stripT1, eddy, [('mask_file', 'in_mask')]),
#                       (reorient, eddy, [('out_file','in_file')]),
#                       (eddy, datasink,[('out_corrected','2_Eddy_Corrected'),
#                                        ('out_rotated_bvecs','2_Eddy_Corrected.@par'),
#                                        ('out_movement_rms','2_Eddy_Corrected.@par.@par'),
#                                        ('out_outlier_report','2_Eddy_Corrected.@par.@par.@par')])
                     ])
preproc_flow.base_dir = workflow_dir
preproc_flow.write_graph(graph2use = 'flat')
preproc = preproc_flow.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 190426-12:02:59,420 nipype.workflow DEBUG:
# 	 (preproc_flow.infosource, preproc_flow.sf): No edge data
# 190426-12:02:59,421 nipype.workflow DEBUG:
# 	 (preproc_flow.infosource, preproc_flow.sf): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 190426-12:02:59,422 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.create_merge): No edge data
# 190426-12:02:59,423 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.create_merge): new edge data: {'connect': [('pe1', 'pe1'), ('pe0', 'pe0')]}
# 190426-12:02:59,423 nipype.workflow DEBUG:
# 	 (preproc_flow.create_merge, preproc_flow.datasink): No edge data
# 190426-12:02:59,424 nipype.workflow DEBUG:
# 	 (preproc_flow.create_merge, preproc_flow.datasink): new edge data: {'connect': [('merged_file', '1_Check_Unwarped')]}
# 190426-12:02:59,425 nipype.workflow DEBUG:
# 	 (preproc_flow.create_merge, preproc_flow.topup): No edge data
# 190426-12:02:59,426 nipype.workflow DEBUG:
# 	 (preproc_flow.create_merge, preproc_flow.topup): new edge data: {'connect': [('merged_file', 'in_file')]}
# 190426-12:02:59,427 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.topup): No edge data
# 190426-12:02:59,427 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.topup): new edge data: {'connect': [('aps', 'encoding_file')]}
# 190426-12:02:59,429 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.datasink): No edge data
# 190426-12:02:59,429 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.datasink): new edge data: {'connect': [('out_corrected', '1_Check_Unwarped.@par')]}
# 190426-12:02:59,431 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.fslroi): No edge data
# 190426-12:02:59,431 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.fslroi): new edge data: {'connect': [('out_corrected', 'in_file')]}
# 190426-12:02:59,432 nipype.workflow DEBUG:
# 	 (preproc_flow.fslroi, preproc_flow.reorient1): No edge data
# 190426-12:02:59,433 nipype.workflow DEBUG:
# 	 (preproc_flow.fslroi, preproc_flow.reorient1): new edge data: {'connect': [('roi_file', 'in_file')]}
# 190426-12:02:59,433 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.register): No edge data
# 190426-12:02:59,434 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.register): new edge data: {'connect': [('t1', 'reference')]}
# 190426-12:02:59,436 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient1, preproc_flow.register): No edge data
# 190426-12:02:59,436 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient1, preproc_flow.register): new edge data: {'connect': [('out_file', 'in_file')]}
# 190426-12:02:59,437 nipype.workflow DEBUG:
# 	 (preproc_flow.register, preproc_flow.datasink): No edge data
# 190426-12:02:59,438 nipype.workflow DEBUG:
# 	 (preproc_flow.register, preproc_flow.datasink): new edge data: {'connect': [('out_file', '1_Check_Unwarped.@par.@par')]}
# 190426-12:02:59,439 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.apptop): No edge data
# 190426-12:02:59,439 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.apptop): new edge data: {'connect': [('out_fieldcoef', 'in_topup_fieldcoef'), ('out_movpar', 'in_topup_movpar')]}
# 190426-12:02:59,440 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.apptop): No edge data
# 190426-12:02:59,441 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.apptop): new edge data: {'connect': [('pe0', 'in_files'), ('aps', 'encoding_file')]}
# 190426-12:02:59,442 nipype.workflow DEBUG:
# 	 (preproc_flow.apptop, preproc_flow.datasink): No edge data
# 190426-12:02:59,443 nipype.workflow DEBUG:
# 	 (preproc_flow.apptop, preproc_flow.datasink): new edge data: {'connect': [('out_corrected', '1_Check_Unwarped.@par.@par.@par')]}
# 190426-12:02:59,443 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.stripT1): No edge data
# 190426-12:02:59,444 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.stripT1): new edge data: {'connect': [('t1', 'in_file')]}
# 190426-12:02:59,445 nipype.workflow DEBUG:
# 	 (preproc_flow.stripT1, preproc_flow.datasink): No edge data
# 190426-12:02:59,446 nipype.workflow DEBUG:
# 	 (preproc_flow.stripT1, preproc_flow.datasink): new edge data: {'connect': [('out_file', '1_Check_Unwarped.@par.@par.@par.@par'), ('mask_file', '1_Check_Unwarped.@par.@par.@par.@par.@par')]}
# 190426-12:02:59,447 nipype.workflow DEBUG:
# 	 (preproc_flow.apptop, preproc_flow.reorient): No edge data
# 190426-12:02:59,448 nipype.workflow DEBUG:
# 	 (preproc_flow.apptop, preproc_flow.reorient): new edge data: {'connect': [('out_corrected', 'in_file')]}
# 190426-12:02:59,449 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient, preproc_flow.datasink): No edge data
# 190426-12:02:59,449 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient, preproc_flow.datasink): new edge data: {'connect': [('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par')]}
# 190426-12:02:59,450 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient, preproc_flow.resample): No edge data
# 190426-12:02:59,450 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient, preproc_flow.resample): new edge data: {'connect': [('out_file', 'in_file')]}
# 190426-12:02:59,451 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.resample): No edge data
# 190426-12:02:59,452 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.resample): new edge data: {'connect': [('t1', 'reference')]}
# 190426-12:02:59,452 nipype.workflow DEBUG:
# 	 (preproc_flow.register, preproc_flow.resample): No edge data
# 190426-12:02:59,453 nipype.workflow DEBUG:
# 	 (preproc_flow.register, preproc_flow.resample): new edge data: {'connect': [('out_matrix_file', 'in_matrix_file')]}
# 190426-12:02:59,454 nipype.workflow DEBUG:
# 	 (preproc_flow.resample, preproc_flow.datasink): No edge data
# 190426-12:02:59,455 nipype.workflow DEBUG:
# 	 (preproc_flow.resample, preproc_flow.datasink): new edge data: {'connect': [('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par.@par')]}
# 190426-12:02:59,456 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: preproc_flow
# 190426-12:02:59,463 nipype.workflow DEBUG:
# 	 expanding workflow: preproc_flow
# 190426-12:02:59,465 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.infosource
# 190426-12:02:59,466 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.sf
# 190426-12:02:59,467 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.stripT1
# 190426-12:02:59,468 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.create_merge
# 190426-12:02:59,469 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.topup
# 190426-12:02:59,470 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.apptop
# 190426-12:02:59,470 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.reorient
# 190426-12:02:59,471 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.fslroi
# 190426-12:02:59,472 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.reorient1
# 190426-12:02:59,473 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.register
# 190426-12:02:59,473 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.resample
# 190426-12:02:59,474 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.datasink
# 190426-12:02:59,475 nipype.workflow DEBUG:
# 	 finished expanding workflow: preproc_flow
# 190426-12:02:59,480 nipype.workflow DEBUG:
# 	 using input graph
# 190426-12:03:03,466 nipype.workflow DEBUG:
# 	 creating dot graph
# 190426-12:03:03,673 nipype.workflow INFO:
# 	 Generated workflow graph: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/graph.png (graph2use=flat, simple_form=True).
# 190426-12:03:04,218 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=4, mem_gb=28.80, cwd=/Users/myelin/Dropbox/Github/Diffusion)
# 190426-12:03:04,232 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: preproc_flow
# 190426-12:03:04,237 nipype.workflow DEBUG:
# 	 expanding workflow: preproc_flow
# 190426-12:03:04,238 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.infosource
# 190426-12:03:04,239 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.sf
# 190426-12:03:04,240 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.stripT1
# 190426-12:03:04,242 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.create_merge
# 190426-12:03:04,242 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.topup
# 190426-12:03:04,243 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.apptop
# 190426-12:03:04,244 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.reorient
# 190426-12:03:04,244 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.fslroi
# 190426-12:03:04,245 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.reorient1
# 190426-12:03:04,245 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.register
# 190426-12:03:04,247 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.resample
# 190426-12:03:04,247 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.datasink
# 190426-12:03:04,248 nipype.workflow DEBUG:
# 	 finished expanding workflow: preproc_flow
# 190426-12:03:04,249 nipype.workflow INFO:
# 	 Workflow preproc_flow settings: ['check', 'execution', 'logging', 'monitoring']
# 190426-12:03:04,253 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 190426-12:03:04,254 nipype.workflow DEBUG:
# 	 Detected iterable nodes [preproc_flow.infosource]
# 190426-12:03:04,255 nipype.workflow DEBUG:
# 	 Expanding the iterable node preproc_flow.infosource...
# 190426-12:03:04,256 nipype.workflow DEBUG:
# 	 node: preproc_flow.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x1220e8510>}
# 190426-12:03:04,257 nipype.workflow DEBUG:
# 	 ('subnodes:', [preproc_flow.infosource, preproc_flow.sf, preproc_flow.create_merge, preproc_flow.datasink, preproc_flow.topup, preproc_flow.fslroi, preproc_flow.reorient1, preproc_flow.register, preproc_flow.resample, preproc_flow.apptop, preproc_flow.reorient, preproc_flow.stripT1])
# 190426-12:03:04,263 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 001-prac
# 190426-12:03:04,263 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_001-prac
# 190426-12:03:04,265 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 190426-12:03:04,266 nipype.workflow DEBUG:
# 	 [Node] sf - setting input subject_id = 001-prac
# 190426-12:03:04,266 nipype.workflow DEBUG:
# 	 Removed the identity node preproc_flow.infosource from the graph.
# 190426-12:03:04,351 nipype.workflow DEBUG:
# 	 Performing depth first search
# 190426-12:03:04,354 nipype.workflow INFO:
# 	 Running in parallel.
# 190426-12:03:04,358 nipype.workflow DEBUG:
# 	 Progress: 11 jobs, 0/0/1 (done/running/ready), 0/11 (pending_tasks/waiting).
# 190426-12:03:04,359 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-12:03:04,360 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190426-12:03:04,419 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.sf ID=0 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190426-12:03:04,421 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:04,422 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data'), ('force_lists', False), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '001-prac')], 65be05be8164d1de39abacfdd6cc1e45, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45.json']
# 190426-12:03:04,424 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.sf".
# 190426-12:03:04,424 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.sf" locally: cached=True, updated=True.
# 190426-12:03:04,442 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.sf (taskid=1).
# 190426-12:03:04,447 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.sf" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf".
# 190426-12:03:04,454 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data'), ('force_lists', False), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '001-prac')], 65be05be8164d1de39abacfdd6cc1e45, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45.json']
# 190426-12:03:04,460 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.sf".
# 190426-12:03:04,464 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "preproc_flow.sf"
# 190426-12:03:04,468 nipype.utils DEBUG:
# 	 Removing contents of /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf
# 190426-12:03:04,558 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_report
# 190426-12:03:04,562 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_report/report.rst"
# 190426-12:03:04,570 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190426-12:03:04,650 nipype.workflow DEBUG:
# 	 Needed files: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.bval;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.bval;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.bvec;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.bvec;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/index.txt;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/acqparams.txt;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/transform.txt;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45_unfinished.json;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_inputs.pklz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_node.pklz
# 190426-12:03:04,654 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_report
# 190426-12:03:04,659 nipype.workflow DEBUG:
# 	 Removing files:
# 190426-12:03:04,665 nipype.workflow DEBUG:
# 	 saved results in /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:04,669 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/_report/report.rst"
# 190426-12:03:04,679 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-12:03:04,687 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.sf".
# 190426-12:03:06,359 nipype.workflow DEBUG:
# 	 Progress: 11 jobs, 0/1/0 (done/running/ready), 1/10 (pending_tasks/waiting).
# 190426-12:03:06,360 nipype.workflow INFO:
# 	 [Job 0] Completed (preproc_flow.sf).
# 190426-12:03:06,362 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-12:03:06,363 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190426-12:03:06,439 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.stripT1 ID=1 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190426-12:03:06,439 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:06,440 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-12:03:06,441 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:06,442 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:06,444 nipype.workflow DEBUG:
# 	 output: t1
# 190426-12:03:06,445 nipype.workflow DEBUG:
# 	 [Node] stripT1 - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz
# 190426-12:03:06,465 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz', '2c3458ce0e6302dcea0d7ce8c1271543')), ('mask', True), ('out_file', 'T1_stripped_anat.nii.gz'), ('output_type', 'NIFTI_GZ')], 8b1df0330e6f9b0bdd1f9a12b16f9bb7, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/stripT1/_0x8b1df0330e6f9b0bdd1f9a12b16f9bb7.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/stripT1/_0x8b1df0330e6f9b0bdd1f9a12b16f9bb7.json']
# 190426-12:03:06,465 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.stripT1".
# 190426-12:03:06,467 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.stripT1" locally: cached=True, updated=True.
# 190426-12:03:06,467 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.stripT1 with ID 1.
# 190426-12:03:06,468 nipype.workflow INFO:
# 	 [Job 1] Cached (preproc_flow.stripT1).
# 190426-12:03:06,470 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.create_merge ID=2 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 190426-12:03:06,470 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:06,471 nipype.workflow DEBUG:
# 	 input: pe1
# 190426-12:03:06,472 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:06,472 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:06,475 nipype.workflow DEBUG:
# 	 output: pe1
# 190426-12:03:06,475 nipype.workflow DEBUG:
# 	 [Node] create_merge - setting input pe1 = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.nii.gz
# 190426-12:03:06,476 nipype.workflow DEBUG:
# 	 input: pe0
# 190426-12:03:06,477 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:06,478 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:06,480 nipype.workflow DEBUG:
# 	 output: pe0
# 190426-12:03:06,480 nipype.workflow DEBUG:
# 	 [Node] create_merge - setting input pe0 = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.nii.gz
# 190426-12:03:06,506 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('function_str', "def create_merged_files(pe1, pe0):\n    from nipype.interfaces import fsl\n    from os.path import abspath\n    fslroi1 = fsl.ExtractROI(in_file = pe1, t_min = 0, t_size = 1, roi_file = 'pe1_1vol.nii.gz').run()  \n    fslroi2 = fsl.ExtractROI(in_file = pe0, t_min = 0, t_size = 1, roi_file = 'pe0_1vol.nii.gz').run()  \n    merge = fsl.Merge(in_files = ['pe1_1vol.nii.gz', 'pe0_1vol.nii.gz'], \n                      dimension = 't', merged_file = 'pe1_pe0_merged.nii.gz').run()\n    merged_file = abspath('pe1_pe0_merged.nii.gz')\n    return merged_file\n"), ('pe0', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.nii.gz', '0620b921ab7f61df684a27149fabe4e4')), ('pe1', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.nii.gz', 'e2a154b5889ffb52a3626b3dedb2b730'))], 704321ffd755e84a53b23504b0e87155, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/create_merge/_0x704321ffd755e84a53b23504b0e87155.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/create_merge/_0x704321ffd755e84a53b23504b0e87155.json']
# 190426-12:03:06,507 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.create_merge".
# 190426-12:03:06,508 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.create_merge" locally: cached=True, updated=True.
# 190426-12:03:06,508 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.create_merge with ID 2.
# 190426-12:03:06,510 nipype.workflow INFO:
# 	 [Job 2] Cached (preproc_flow.create_merge).
# 190426-12:03:08,358 nipype.workflow DEBUG:
# 	 Progress: 11 jobs, 3/0/1 (done/running/ready), 0/8 (pending_tasks/waiting).
# 190426-12:03:08,359 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-12:03:08,361 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190426-12:03:08,410 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.topup ID=3 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190426-12:03:08,411 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:08,411 nipype.workflow DEBUG:
# 	 input: encoding_file
# 190426-12:03:08,412 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:08,412 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:08,415 nipype.workflow DEBUG:
# 	 output: aps
# 190426-12:03:08,415 nipype.workflow DEBUG:
# 	 [Node] topup - setting input encoding_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/acqparams.txt
# 190426-12:03:08,416 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-12:03:08,417 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/create_merge/result_create_merge.pklz
# 190426-12:03:08,417 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/create_merge/result_create_merge.pklz
# 190426-12:03:08,498 nipype.workflow DEBUG:
# 	 output: merged_file
# 190426-12:03:08,499 nipype.workflow DEBUG:
# 	 [Node] topup - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/create_merge/pe1_pe0_merged.nii.gz
# 190426-12:03:08,524 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('config', 'b02b0.cnf'), ('encoding_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/acqparams.txt', '7411cdbb2460ae66c3413f466d4e1068')), ('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/create_merge/pe1_pe0_merged.nii.gz', '93a91cb5dfe416bd1c1dffc455742646')), ('out_jac_prefix', 'jac'), ('out_mat_prefix', 'xfm'), ('out_warp_prefix', 'warpfield'), ('output_type', 'NIFTI_GZ')], 2cc746a9307c5b0304fcfa0969620528, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/_0x2cc746a9307c5b0304fcfa0969620528.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/_0x2cc746a9307c5b0304fcfa0969620528.json']
# 190426-12:03:08,525 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.topup".
# 190426-12:03:08,526 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.topup" locally: cached=True, updated=True.
# 190426-12:03:08,527 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.topup with ID 3.
# 190426-12:03:08,528 nipype.workflow INFO:
# 	 [Job 3] Cached (preproc_flow.topup).
# 190426-12:03:10,360 nipype.workflow DEBUG:
# 	 Progress: 11 jobs, 4/0/2 (done/running/ready), 0/7 (pending_tasks/waiting).
# 190426-12:03:10,361 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-12:03:10,363 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190426-12:03:10,413 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.apptop ID=4 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190426-12:03:10,414 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:10,414 nipype.workflow DEBUG:
# 	 input: in_files
# 190426-12:03:10,415 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:10,416 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:10,418 nipype.workflow DEBUG:
# 	 output: pe0
# 190426-12:03:10,418 nipype.workflow DEBUG:
# 	 [Node] apptop - setting input in_files = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.nii.gz
# 190426-12:03:10,420 nipype.workflow DEBUG:
# 	 input: encoding_file
# 190426-12:03:10,420 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:10,421 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:10,423 nipype.workflow DEBUG:
# 	 output: aps
# 190426-12:03:10,424 nipype.workflow DEBUG:
# 	 [Node] apptop - setting input encoding_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/acqparams.txt
# 190426-12:03:10,425 nipype.workflow DEBUG:
# 	 input: in_topup_fieldcoef
# 190426-12:03:10,426 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/result_topup.pklz
# 190426-12:03:10,427 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/result_topup.pklz
# 190426-12:03:10,485 nipype.workflow DEBUG:
# 	 output: out_fieldcoef
# 190426-12:03:10,486 nipype.workflow DEBUG:
# 	 [Node] apptop - setting input in_topup_fieldcoef = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/pe1_pe0_merged_base_fieldcoef.nii.gz
# 190426-12:03:10,487 nipype.workflow DEBUG:
# 	 input: in_topup_movpar
# 190426-12:03:10,488 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/result_topup.pklz
# 190426-12:03:10,488 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/result_topup.pklz
# 190426-12:03:10,491 nipype.workflow DEBUG:
# 	 output: out_movpar
# 190426-12:03:10,491 nipype.workflow DEBUG:
# 	 [Node] apptop - setting input in_topup_movpar = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/pe1_pe0_merged_base_movpar.txt
# 190426-12:03:10,494 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('encoding_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/acqparams.txt', '7411cdbb2460ae66c3413f466d4e1068')), ('in_files', [('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.nii.gz', '0620b921ab7f61df684a27149fabe4e4')]), ('in_index', [2]), ('in_topup_fieldcoef', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/pe1_pe0_merged_base_fieldcoef.nii.gz', '69bfa93d623b7111505fbac0692850a8')), ('in_topup_movpar', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/pe1_pe0_merged_base_movpar.txt', 'fc96bd36e8cb211e57889ba139484d8d')), ('method', 'jac'), ('out_corrected', 'pe0_applied_topup.nii.gz'), ('output_type', 'NIFTI_GZ')], f13cc7d8afa5125dbab2762c7296b985, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/_0xf13cc7d8afa5125dbab2762c7296b985.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/_0xf13cc7d8afa5125dbab2762c7296b985.json']
# 190426-12:03:10,494 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.apptop".
# 190426-12:03:10,495 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.apptop" locally: cached=True, updated=True.
# 190426-12:03:10,496 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.apptop with ID 4.
# 190426-12:03:10,497 nipype.workflow INFO:
# 	 [Job 4] Cached (preproc_flow.apptop).
# 190426-12:03:10,499 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.fslroi ID=6 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 190426-12:03:10,499 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:10,500 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-12:03:10,501 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/result_topup.pklz
# 190426-12:03:10,502 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/result_topup.pklz
# 190426-12:03:10,504 nipype.workflow DEBUG:
# 	 output: out_corrected
# 190426-12:03:10,504 nipype.workflow DEBUG:
# 	 [Node] fslroi - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/pe1_pe0_merged_corrected.nii.gz
# 190426-12:03:10,506 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi".
# 190426-12:03:10,507 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.fslroi" locally: cached=False, updated=False.
# 190426-12:03:10,509 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.fslroi (taskid=2).
# 190426-12:03:10,513 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.fslroi" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi".
# 190426-12:03:10,521 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi".
# 190426-12:03:10,526 nipype.utils DEBUG:
# 	 Removing contents of /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi
# 190426-12:03:10,531 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi
# 190426-12:03:10,536 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/_report
# 190426-12:03:10,541 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/_report/report.rst"
# 190426-12:03:10,551 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/pe1_pe0_merged_corrected.nii.gz
# 190426-12:03:10,555 nipype.interface DEBUG:
# 	 roi_file_b0_img.nii.gz
# 190426-12:03:10,560 nipype.interface DEBUG:
# 	 t_min_0
# 190426-12:03:10,565 nipype.interface DEBUG:
# 	 t_size_1
# 190426-12:03:10,569 nipype.workflow INFO:
# 	 [Node] Running "fslroi" ("nipype.interfaces.fsl.utils.ExtractROI"), a CommandLine Interface with command:
# fslroi /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/pe1_pe0_merged_corrected.nii.gz b0_img.nii.gz 0 1
# 190426-12:03:10,575 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/pe1_pe0_merged_corrected.nii.gz
# 190426-12:03:10,580 nipype.interface DEBUG:
# 	 roi_file_b0_img.nii.gz
# 190426-12:03:10,584 nipype.interface DEBUG:
# 	 t_min_0
# 190426-12:03:10,588 nipype.interface DEBUG:
# 	 t_size_1
# 190426-12:03:11,172 nipype.workflow DEBUG:
# 	 Needed files: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/b0_img.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/topup/pe1_pe0_merged_corrected.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/_0x27cf9a96a4ae65a398035adba7c247ed_unfinished.json;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/command.txt;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/_inputs.pklz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/_node.pklz
# 190426-12:03:11,177 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/_report
# 190426-12:03:11,181 nipype.workflow DEBUG:
# 	 Removing files:
# 190426-12:03:11,186 nipype.workflow DEBUG:
# 	 saved results in /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/result_fslroi.pklz
# 190426-12:03:11,190 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/_report/report.rst"
# 190426-12:03:11,200 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-12:03:11,205 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.fslroi".
# 190426-12:03:12,360 nipype.workflow DEBUG:
# 	 Progress: 11 jobs, 5/1/1 (done/running/ready), 1/5 (pending_tasks/waiting).
# 190426-12:03:12,361 nipype.workflow INFO:
# 	 [Job 6] Completed (preproc_flow.fslroi).
# 190426-12:03:12,363 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-12:03:12,364 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190426-12:03:12,413 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.reorient ID=5 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190426-12:03:12,414 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:12,415 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-12:03:12,416 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/result_apptop.pklz
# 190426-12:03:12,416 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/result_apptop.pklz
# 190426-12:03:12,558 nipype.workflow DEBUG:
# 	 output: out_corrected
# 190426-12:03:12,559 nipype.workflow DEBUG:
# 	 [Node] reorient - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz
# 190426-12:03:12,574 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz', '021cc8fc5d403b85f066b6b429f6ce18')), ('out_file', 'pe0_applied_topup_reoriented.nii.gz'), ('output_type', 'NIFTI_GZ')], b3e7e76c8007a2ca5bb8812810d4ba76, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/_0xb3e7e76c8007a2ca5bb8812810d4ba76.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/_0xa07640df70b3bdd178fab6458105f847.json']
# 190426-12:03:12,575 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc_flow.reorient".
# 190426-12:03:12,575 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = a07640df70b3bdd178fab6458105f847/b3e7e76c8007a2ca5bb8812810d4ba76
# 190426-12:03:12,695 nipype.workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * in_file: ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz', '021cc8fc5d403b85f066b6b429f6ce18') != ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample/pe0_applied_topup_reoriented_resampled.nii.gz', '48c22c2a7e38829f20aa15bd807e1512']
# 190426-12:03:12,696 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.reorient" locally: cached=True, updated=False.
# 190426-12:03:12,698 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.reorient (taskid=3).
# 190426-12:03:12,699 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.reorient1 ID=7 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 190426-12:03:12,700 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:12,701 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-12:03:12,702 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/result_fslroi.pklz
# 190426-12:03:12,702 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/result_fslroi.pklz
# 190426-12:03:12,704 nipype.workflow DEBUG:
# 	 output: roi_file
# 190426-12:03:12,705 nipype.workflow DEBUG:
# 	 [Node] reorient1 - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/b0_img.nii.gz
# 190426-12:03:12,706 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1".
# 190426-12:03:12,702 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.reorient" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient".190426-12:03:12,707 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.reorient1" locally: cached=False, updated=False.
#
# 190426-12:03:12,709 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.reorient1 (taskid=4).
# 190426-12:03:12,710 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz', '021cc8fc5d403b85f066b6b429f6ce18')), ('out_file', 'pe0_applied_topup_reoriented.nii.gz'), ('output_type', 'NIFTI_GZ')], b3e7e76c8007a2ca5bb8812810d4ba76, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/_0xb3e7e76c8007a2ca5bb8812810d4ba76.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/_0xa07640df70b3bdd178fab6458105f847.json']
# 190426-12:03:12,716 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc_flow.reorient".190426-12:03:12,713 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.reorient1" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1".
#
# 190426-12:03:12,721 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = a07640df70b3bdd178fab6458105f847/b3e7e76c8007a2ca5bb8812810d4ba76190426-12:03:12,721 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1".
#
# 190426-12:03:12,726 nipype.workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * in_file: ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz', '021cc8fc5d403b85f066b6b429f6ce18') != ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample/pe0_applied_topup_reoriented_resampled.nii.gz', '48c22c2a7e38829f20aa15bd807e1512']190426-12:03:12,726 nipype.utils DEBUG:
# 	 Removing contents of /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1
#
# 190426-12:03:12,731 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1190426-12:03:12,731 nipype.utils DEBUG:
# 	 Removing contents of /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient
#
# 190426-12:03:12,736 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/_report
# 190426-12:03:12,741 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/_report/report.rst"
# 190426-12:03:12,752 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/b0_img.nii.gz
# 190426-12:03:12,757 nipype.interface DEBUG:
# 	 out_file_pe1_pe0_topup_reorient.nii.gz
# 190426-12:03:12,762 nipype.workflow INFO:
# 	 [Node] Running "reorient1" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/b0_img.nii.gz pe1_pe0_topup_reorient.nii.gz
# 190426-12:03:12,768 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/b0_img.nii.gz
# 190426-12:03:12,772 nipype.interface DEBUG:
# 	 out_file_pe1_pe0_topup_reorient.nii.gz
# 190426-12:03:12,935 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/_report
# 190426-12:03:12,939 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/_report/report.rst"
# 190426-12:03:12,949 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz
# 190426-12:03:12,953 nipype.interface DEBUG:
# 	 out_file_pe0_applied_topup_reoriented.nii.gz
# 190426-12:03:12,958 nipype.workflow INFO:
# 	 [Node] Running "reorient" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz pe0_applied_topup_reoriented.nii.gz
# 190426-12:03:12,964 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz
# 190426-12:03:12,969 nipype.interface DEBUG:
# 	 out_file_pe0_applied_topup_reoriented.nii.gz
# 190426-12:03:14,365 nipype.workflow DEBUG:
# 	 Progress: 11 jobs, 6/2/0 (done/running/ready), 2/3 (pending_tasks/waiting).
# 190426-12:03:14,366 nipype.workflow DEBUG:
# 	 Tasks currently running: 2. Pending: 2.
# 190426-12:03:14,367 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 2/4.
#                      Currently running:
#                        * preproc_flow.reorient1
#                        * preproc_flow.reorient
# 190426-12:03:15,317 nipype.workflow DEBUG:
# 	 Needed files: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/pe1_pe0_topup_reorient.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/fslroi/b0_img.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/_0x6378fd143053f2446d158c9b6846fc12_unfinished.json;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/command.txt;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/_inputs.pklz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/_node.pklz
# 190426-12:03:15,322 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/_report
# 190426-12:03:15,327 nipype.workflow DEBUG:
# 	 Removing files:
# 190426-12:03:15,375 nipype.workflow DEBUG:
# 	 saved results in /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/result_reorient1.pklz
# 190426-12:03:15,379 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/_report/report.rst"
# 190426-12:03:15,386 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-12:03:15,392 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.reorient1".
# 190426-12:03:16,368 nipype.workflow INFO:
# 	 [Job 7] Completed (preproc_flow.reorient1).
# 190426-12:03:16,369 nipype.workflow DEBUG:
# 	 Tasks currently running: 1. Pending: 1.
# 190426-12:03:16,371 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 3/4.
#                      Currently running:
#                        * preproc_flow.reorient
# 190426-12:03:16,420 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.register ID=8 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 190426-12:03:16,421 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:16,422 nipype.workflow DEBUG:
# 	 input: reference
# 190426-12:03:16,422 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:16,423 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:16,424 nipype.workflow DEBUG:
# 	 output: t1
# 190426-12:03:16,425 nipype.workflow DEBUG:
# 	 [Node] register - setting input reference = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz
# 190426-12:03:16,426 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-12:03:16,427 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/result_reorient1.pklz
# 190426-12:03:16,427 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/result_reorient1.pklz
# 190426-12:03:16,429 nipype.workflow DEBUG:
# 	 output: out_file
# 190426-12:03:16,430 nipype.workflow DEBUG:
# 	 [Node] register - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient1/pe1_pe0_topup_reorient.nii.gz
# 190426-12:03:16,432 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register".
# 190426-12:03:16,433 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.register" locally: cached=False, updated=False.
# 190426-12:03:16,435 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.register (taskid=5).
# 190426-12:03:16,437 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.register" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register".
# 190426-12:03:16,441 nipype.workflow DEBUG:
# ...
# 190426-12:03:32,923 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/_report
# 190426-12:03:32,927 nipype.workflow DEBUG:
# 	 Removing files:
# 190426-12:03:32,932 nipype.workflow DEBUG:
# 	 saved results in /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/result_register.pklz
# 190426-12:03:32,936 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/_report/report.rst"
# 190426-12:03:32,942 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-12:03:32,947 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.register".
# 190426-12:03:34,372 nipype.workflow INFO:
# 	 [Job 8] Completed (preproc_flow.register).
# 190426-12:03:34,374 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-12:03:34,375 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190426-12:03:34,423 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.resample ID=9 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190426-12:03:34,424 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-12:03:34,426 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-12:03:34,427 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/result_reorient.pklz
# 190426-12:03:34,427 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/result_reorient.pklz
# 190426-12:03:34,429 nipype.workflow DEBUG:
# 	 output: out_file
# 190426-12:03:34,430 nipype.workflow DEBUG:
# 	 [Node] resample - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/pe0_applied_topup_reoriented.nii.gz
# 190426-12:03:34,431 nipype.workflow DEBUG:
# 	 input: reference
# 190426-12:03:34,432 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:34,432 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-12:03:34,434 nipype.workflow DEBUG:
# 	 output: t1
# 190426-12:03:34,434 nipype.workflow DEBUG:
# 	 [Node] resample - setting input reference = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz
# 190426-12:03:34,435 nipype.workflow DEBUG:
# 	 input: in_matrix_file
# 190426-12:03:34,436 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/result_register.pklz
# 190426-12:03:34,436 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/result_register.pklz
# 190426-12:03:34,438 nipype.workflow DEBUG:
# 	 output: out_matrix_file
# 190426-12:03:34,439 nipype.workflow DEBUG:
# 	 [Node] resample - setting input in_matrix_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/pe1_pe0_topup_reorient_reg.mat
# 190426-12:03:34,451 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('apply_xfm', True), ('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/pe0_applied_topup_reoriented.nii.gz', '64873d358ea3f317b641e851626142cd')), ('in_matrix_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/pe1_pe0_topup_reorient_reg.mat', 'bc03ce92c0e91790b6ef90c70fb3755d')), ('out_file', 'pe0_applied_topup_reoriented_resampled.nii.gz'), ('output_type', 'NIFTI_GZ'), ('reference', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz', '2c3458ce0e6302dcea0d7ce8c1271543'))], 0219c043dd268f366bfe0635654edcf2, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample/_0x0219c043dd268f366bfe0635654edcf2.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample/_0xe37e82e12558263a3ad5cd94c644f681.json']
# 190426-12:03:34,451 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc_flow.resample".
# 190426-12:03:34,452 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = e37e82e12558263a3ad5cd94c644f681/0219c043dd268f366bfe0635654edcf2
# 190426-12:03:34,531 nipype.workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * in_file: ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/pe0_applied_topup_reoriented.nii.gz', '64873d358ea3f317b641e851626142cd') != ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz', '021cc8fc5d403b85f066b6b429f6ce18']
#             * in_matrix_file: ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/pe1_pe0_topup_reorient_reg.mat', 'bc03ce92c0e91790b6ef90c70fb3755d') != ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/transform.txt', '050279bb50d982aa96cc457d340a03ca']
# 190426-12:03:34,532 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.resample" locally: cached=True, updated=False.
# 190426-12:03:34,534 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.resample (taskid=6).
# 190426-12:03:34,535 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.resample" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample".
# 190426-12:03:34,540 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('apply_xfm', True), ('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/pe0_applied_topup_reoriented.nii.gz', '64873d358ea3f317b641e851626142cd')), ('in_matrix_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/pe1_pe0_topup_reorient_reg.mat', 'bc03ce92c0e91790b6ef90c70fb3755d')), ('out_file', 'pe0_applied_topup_reoriented_resampled.nii.gz'), ('output_type', 'NIFTI_GZ'), ('reference', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz', '2c3458ce0e6302dcea0d7ce8c1271543'))], 0219c043dd268f366bfe0635654edcf2, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample/_0x0219c043dd268f366bfe0635654edcf2.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample/_0xe37e82e12558263a3ad5cd94c644f681.json']
# 190426-12:03:34,544 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc_flow.resample".
# 190426-12:03:34,548 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = e37e82e12558263a3ad5cd94c644f681/0219c043dd268f366bfe0635654edcf2
# 190426-12:03:34,553 nipype.workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * in_file: ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/pe0_applied_topup_reoriented.nii.gz', '64873d358ea3f317b641e851626142cd') != ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/apptop/pe0_applied_topup.nii.gz', '021cc8fc5d403b85f066b6b429f6ce18']
#             * in_matrix_file: ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/pe1_pe0_topup_reorient_reg.mat', 'bc03ce92c0e91790b6ef90c70fb3755d') != ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/transform.txt', '050279bb50d982aa96cc457d340a03ca']
# 190426-12:03:34,569 nipype.utils DEBUG:
# 	 Removing contents of /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample
# 190426-12:03:34,608 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample/_report
# 190426-12:03:34,613 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/resample/_report/report.rst"
# 190426-12:03:34,619 nipype.interface DEBUG:
# 	 apply_xfm_True
# 190426-12:03:34,624 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/pe0_applied_topup_reoriented.nii.gz
# 190426-12:03:34,628 nipype.interface DEBUG:
# 	 in_matrix_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/pe1_pe0_topup_reorient_reg.mat
# 190426-12:03:34,633 nipype.interface DEBUG:
# 	 out_file_pe0_applied_topup_reoriented_resampled.nii.gz
# 190426-12:03:34,637 nipype.interface DEBUG:
# 	 out_matrix_file_pe0_applied_topup_reoriented_flirt.mat
# 190426-12:03:34,642 nipype.interface DEBUG:
# 	 reference_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz
# 190426-12:03:34,647 nipype.workflow INFO:
# 	 [Node] Running "resample" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/pe0_applied_topup_reoriented.nii.gz -ref /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz -out pe0_applied_topup_reoriented_resampled.nii.gz -omat pe0_applied_topup_reoriented_flirt.mat -applyxfm -init /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/pe1_pe0_topup_reorient_reg.mat
# 190426-12:03:34,653 nipype.interface DEBUG:
# 	 apply_xfm_True
# 190426-12:03:34,657 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/reorient/pe0_applied_topup_reoriented.nii.gz
# 190426-12:03:34,662 nipype.interface DEBUG:
# 	 in_matrix_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/preproc_flow/_subject_id_001-prac/register/pe1_pe0_topup_reorient_reg.mat
# 190426-12:03:34,667 nipype.interface DEBUG:
# 	 out_file_pe0_applied_topup_reoriented_resampled.nii.gz
# 190426-12:03:34,671 nipype.interface DEBUG:
# 	 out_matrix_file_pe0_applied_topup_reoriented_flirt.mat
# 190426-12:03:34,675 nipype.interface DEBUG:
# 	 reference_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/125-skullstripped_anat.nii.gz
# 190426-12:03:36,373 nipype.workflow DEBUG:
# 	 Progress: 11 jobs, 9/1/0 (done/running/ready), 1/1 (pending_tasks/waiting).
# 190426-12:03:36,374 nipype.workflow DEBUG:
# 	 Tasks currently running: 1. Pending: 1.
# 190426-12:03:36,375 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 3/4.
#                      Currently running:
#                        * preproc_flow.resample
# Process Process-4:
# Process Process-1:
# Process Process-3:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/concurrent/futures/process.py", line 169, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/local/anaconda3/lib/python3.6/concurrent/futures/process.py", line 169, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/anaconda3/lib/python3.6/concurrent/futures/process.py", line 169, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/local/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# exception calling callback for <Future at 0x1221007b8 state=finished raised BrokenProcessPool>
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/concurrent/futures/_base.py", line 324, in _invoke_callbacks
#     callback(self)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/multiproc.py", line 151, in _async_callback
#     result = args.result()
#   File "/usr/local/anaconda3/lib/python3.6/concurrent/futures/_base.py", line 425, in result
#     return self.__get_result()
#   File "/usr/local/anaconda3/lib/python3.6/concurrent/futures/_base.py", line 384, in __get_result
#     raise self._exception
# concurrent.futures.process.BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-db523b51d13e> in <module>()
#      39 preproc_flow.base_dir = workflow_dir
#      40 preproc_flow.write_graph(graph2use = 'flat')
# ---> 41 preproc = preproc_flow.run('MultiProc', plugin_args={'n_procs': 4})
#
# /usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     597         if str2bool(self.config['execution']['create_report']):
#     598             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 599         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     600         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     601         if str2bool(self.config['execution']['write_provenance']):
#
# /usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/base.py in run(self, graph, config, updatehash)
#     186
#     187             sleep_til = loop_start + poll_sleep_secs
# --> 188             sleep(max(0, sleep_til - time()))
#     189
#     190         self._remove_node_dirs()
#
# KeyboardInterrupt:
