# %%
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber 
from nipype.interfaces.utility import IdentityInterface, Function    
from nipype.pipeline.engine import Node, Workflow, JoinNode, MapNode
from nipype.interfaces import fsl
from nipype.interfaces import brainsuite
from nipype.interfaces.io import SelectFiles, DataSink, DataGrabber
from shutil import copyfile
from pandas import Series
from glob import glob
from os.path import abspath, expanduser, join
from os import chdir, remove, getcwd
from nipype import config, logging
from datetime import date
today = str(date.today())
config.enable_debug_mode()

# %%
user = expanduser('~')
user
# Out:
# '/Users/lucindasisk'

# %%
#Set variables
subject_list = ['001-prac']

user = expanduser('~')
home = join(user,'Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data')
if user == '/Users/lucindasisk':
    workflow_dir = join(home, 'workflow_LS')
    data_dir = join(home, 'DataDir_LS')
elif user == '/Users/myelin':
    workflow_dir = join(home, 'workflow')
    data_dir = join(home, 'DataDir')
index = join(user, 'index.txt')
aps = join(user, 'acqparams.txt')

# %%
#Setup Datasink, Infosource, Selectfiles

datasink = Node(DataSink(base_directory = data_dir),
                   name='datasink')

#Set infosource iterables
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

#SelectFiles
template = dict(t1 = join(home,'{subject_id}/t1w.nii.gz'),
                pe1= join(home, '{subject_id}/dti_pe1.nii.gz'),
                pe0= join(home, '{subject_id}/dti_pe0.nii.gz'),
                bvalpe1 = join(home,'{subject_id}/dti_pe1.bval'),
                bvalpe0 = join(home,'{subject_id}/dti_pe0.bval'),
                bvecpe1 = join(home,'{subject_id}/dti_pe1.bvec'),
                bvecpe0 = join(home,'{subject_id}/dti_pe0.bvec'),
                index = join(home, 'index.txt'),
                aps = join(home, 'acqparams.txt'))

sf = Node(SelectFiles(template, 
                      base_directory = home),
          name = 'sf')

# %%
def create_merged_files(pe1, pe0):
    from nipype.interfaces import fsl
    fslroi1 = fsl.ExtractROI(in_file = pe1, t_min = 0, t_size = 1, roi_file = 'pe1_1vol.nii.gz').run()  
    fslroi2 = fsl.ExtractROI(in_file = pe0, t_min = 0, t_size = 1, roi_file = 'pe0_1vol.nii.gz').run()  
    merge = fsl.Merge(in_files = ['pe1_1vol.nii.gz', 'pe0_1vol.nii.gz'], 
                      dimension = 't', merged_file = 'pe1_pe0_merged.nii.gz').run()
    return ['pe1_pe0_merged.nii.gz', 'pe1_1vol.nii.gz']

create_merge = Node(Function(input_names=['pe1', 'pe0'],
                             output_names=['merged_file'],
                             function = create_merged_files),
                    name='create_merge')

# %%
preproc_flow = Workflow(name = 'preproc_flow')
preproc_flow.connect([(infosource, sf, [('subject_id','subject_id')]),
                      (sf, create_merge, [('pe1', 'pe1'),
                                         ('pe0', 'pe0')]),
                      (create_merge, datasink, [('merged_file', 'test')])
#                       (fslroi1, conc_int, [('roi_file', 'in_file1')]),
#                       (fslroi2, conc_int, [('roi_file', 'in_file2')]),
#                       (conc_int, merge, [('file_list', 'in_files')])
                     ])
preproc_flow.base_dir = workflow_dir
#preproc_flow.write_graph(graph2use = 'flat')
preproc = preproc_flow.run('MultiProc', plugin_args={'n_procs': 2})
# Out:
# 190404-14:39:06,310 nipype.workflow DEBUG:
# 	 (preproc_flow.infosource, preproc_flow.sf): No edge data
# 190404-14:39:06,311 nipype.workflow DEBUG:
# 	 (preproc_flow.infosource, preproc_flow.sf): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 190404-14:39:06,312 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.create_merge): No edge data
# 190404-14:39:06,312 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.create_merge): new edge data: {'connect': [('pe1', 'pe1'), ('pe0', 'pe0')]}
# 190404-14:39:06,313 nipype.workflow DEBUG:
# 	 (preproc_flow.create_merge, preproc_flow.datasink): No edge data
# 190404-14:39:06,314 nipype.workflow DEBUG:
# 	 (preproc_flow.create_merge, preproc_flow.datasink): new edge data: {'connect': [('merged_file', 'test')]}
# 190404-14:39:06,328 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=2, mem_gb=28.80, cwd=/Users/lucindasisk/Dropbox/Github/Diffusion)
# 190404-14:39:06,331 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: preproc_flow
# 190404-14:39:06,335 nipype.workflow DEBUG:
# 	 expanding workflow: preproc_flow
# 190404-14:39:06,336 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.infosource
# 190404-14:39:06,337 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.sf
# 190404-14:39:06,337 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.create_merge
# 190404-14:39:06,338 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.datasink
# 190404-14:39:06,339 nipype.workflow DEBUG:
# 	 finished expanding workflow: preproc_flow
# 190404-14:39:06,340 nipype.workflow INFO:
# 	 Workflow preproc_flow settings: ['check', 'execution', 'logging', 'monitoring']
# 190404-14:39:06,343 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 190404-14:39:06,344 nipype.workflow DEBUG:
# 	 Detected iterable nodes [preproc_flow.infosource]
# 190404-14:39:06,344 nipype.workflow DEBUG:
# 	 Expanding the iterable node preproc_flow.infosource...
# 190404-14:39:06,345 nipype.workflow DEBUG:
# 	 node: preproc_flow.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x1517f05840>}
# 190404-14:39:06,346 nipype.workflow DEBUG:
# 	 ('subnodes:', [preproc_flow.infosource, preproc_flow.sf, preproc_flow.create_merge, preproc_flow.datasink])
# 190404-14:39:06,349 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 001-prac
# 190404-14:39:06,350 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_001-prac
# 190404-14:39:06,351 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 190404-14:39:06,352 nipype.workflow DEBUG:
# 	 [Node] sf - setting input subject_id = 001-prac
# 190404-14:39:06,353 nipype.workflow DEBUG:
# 	 Removed the identity node preproc_flow.infosource from the graph.
# 190404-14:39:06,361 nipype.workflow DEBUG:
# 	 Performing depth first search
# 190404-14:39:06,363 nipype.workflow INFO:
# 	 Running in parallel.
# 190404-14:39:06,366 nipype.workflow DEBUG:
# 	 Progress: 3 jobs, 0/0/1 (done/running/ready), 0/3 (pending_tasks/waiting).
# 190404-14:39:06,366 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190404-14:39:06,368 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190404-14:39:06,414 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.sf ID=0 (0.20GB, 1 threads). Free: 28.60GB, 1 threads.
# 190404-14:39:06,415 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190404-14:39:06,417 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf".
# 190404-14:39:06,418 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.sf" locally: cached=False, updated=False.
# 190404-14:39:06,430 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.sf (taskid=1).
# 190404-14:39:06,436 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.sf" in "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf".
# 190404-14:39:06,444 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf".
# 190404-14:39:06,449 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf
# 190404-14:39:06,454 nipype.utils DEBUG:
# 	 Creating directory /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf
# 190404-14:39:06,460 nipype.utils DEBUG:
# 	 Creating directory /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/_report
# 190404-14:39:06,465 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/_report/report.rst"
# 190404-14:39:06,473 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190404-14:39:06,499 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/t1w.nii.gz;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.nii.gz;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.nii.gz;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.bval;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.bval;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.bvec;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.bvec;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/index.txt;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/acqparams.txt;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/_0x9cf2329852fdb4d15f2ceb9b07eb4e7c_unfinished.json;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/_inputs.pklz;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/_node.pklz
# 190404-14:39:06,505 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/_report
# 190404-14:39:06,510 nipype.workflow DEBUG:
# 	 Removing files:
# 190404-14:39:06,516 nipype.workflow DEBUG:
# 	 saved results in /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190404-14:39:06,522 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/_report/report.rst"
# 190404-14:39:06,528 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190404-14:39:06,536 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.sf".
# 190404-14:39:08,369 nipype.workflow DEBUG:
# 	 Progress: 3 jobs, 0/1/0 (done/running/ready), 1/2 (pending_tasks/waiting).
# 190404-14:39:08,371 nipype.workflow INFO:
# 	 [Job 0] Completed (preproc_flow.sf).
# 190404-14:39:08,373 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190404-14:39:08,374 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190404-14:39:08,433 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.create_merge ID=1 (0.20GB, 1 threads). Free: 28.60GB, 1 threads.
# 190404-14:39:08,434 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190404-14:39:08,435 nipype.workflow DEBUG:
# 	 input: pe1
# 190404-14:39:08,436 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190404-14:39:08,436 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190404-14:39:08,438 nipype.workflow DEBUG:
# 	 output: pe1
# 190404-14:39:08,439 nipype.workflow DEBUG:
# 	 [Node] create_merge - setting input pe1 = /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.nii.gz
# 190404-14:39:08,440 nipype.workflow DEBUG:
# 	 input: pe0
# 190404-14:39:08,440 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190404-14:39:08,441 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190404-14:39:08,443 nipype.workflow DEBUG:
# 	 output: pe0
# 190404-14:39:08,444 nipype.workflow DEBUG:
# 	 [Node] create_merge - setting input pe0 = /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.nii.gz
# 190404-14:39:08,446 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge".
# 190404-14:39:08,446 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.create_merge" locally: cached=False, updated=False.
# 190404-14:39:08,448 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.create_merge (taskid=2).
# 190404-14:39:08,450 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.create_merge" in "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge".
# 190404-14:39:08,458 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge".
# 190404-14:39:08,463 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge
# 190404-14:39:08,469 nipype.utils DEBUG:
# 	 Creating directory /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge
# 190404-14:39:08,474 nipype.utils DEBUG:
# 	 Creating directory /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/_report
# 190404-14:39:08,479 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/_report/report.rst"
# 190404-14:39:08,486 nipype.workflow INFO:
# 	 [Node] Running "create_merge" ("nipype.interfaces.utility.wrappers.Function")
# 190404-14:39:08,507 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.nii.gz
# 190404-14:39:08,513 nipype.interface DEBUG:
# 	 roi_file_pe1_1vol.nii.gz
# 190404-14:39:08,518 nipype.interface DEBUG:
# 	 t_min_0
# 190404-14:39:08,523 nipype.interface DEBUG:
# 	 t_size_1
# 190404-14:39:08,738 nipype.interface DEBUG:
# 	 in_file_/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.nii.gz
# 190404-14:39:08,743 nipype.interface DEBUG:
# 	 roi_file_pe0_1vol.nii.gz
# 190404-14:39:08,748 nipype.interface DEBUG:
# 	 t_min_0
# 190404-14:39:08,753 nipype.interface DEBUG:
# 	 t_size_1
# 190404-14:39:09,224 nipype.interface DEBUG:
# 	 in_files_['pe1_1vol.nii.gz', 'pe0_1vol.nii.gz']
# 190404-14:39:09,228 nipype.interface DEBUG:
# 	 merged_file_pe1_pe0_merged.nii.gz
# 190404-14:39:09,379 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.nii.gz;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe1.nii.gz;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/_0x429cd92bb8601c275f2a2ac15b0444af_unfinished.json;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/_inputs.pklz;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/_node.pklz
# 190404-14:39:09,384 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/_report
# 190404-14:39:09,388 nipype.workflow DEBUG:
# 	 Removing files:
# 190404-14:39:09,393 nipype.workflow DEBUG:
# 	 saved results in /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/result_create_merge.pklz
# 190404-14:39:09,398 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/_report/report.rst"
# 190404-14:39:09,403 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190404-14:39:09,409 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.create_merge".
# 190404-14:39:10,369 nipype.workflow DEBUG:
# 	 Progress: 3 jobs, 1/1/0 (done/running/ready), 1/1 (pending_tasks/waiting).
# 190404-14:39:10,370 nipype.workflow INFO:
# 	 [Job 1] Completed (preproc_flow.create_merge).
# 190404-14:39:10,371 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190404-14:39:10,372 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190404-14:39:10,408 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.datasink ID=2 (0.20GB, 1 threads). Free: 28.60GB, 1 threads.
# 190404-14:39:10,409 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190404-14:39:10,409 nipype.workflow DEBUG:
# 	 input: test
# 190404-14:39:10,410 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/result_create_merge.pklz
# 190404-14:39:10,411 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/create_merge/result_create_merge.pklz
# 190404-14:39:10,412 nipype.workflow DEBUG:
# 	 output: merged_file
# 190404-14:39:10,413 nipype.workflow DEBUG:
# 	 [Node] datasink - setting input test = ['pe1_pe0_merged.nii.gz', 'pe1_1vol.nii.gz']
# 190404-14:39:10,414 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink".
# 190404-14:39:10,415 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.datasink" locally: cached=False, updated=False.
# 190404-14:39:10,417 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.datasink (taskid=3).
# 190404-14:39:10,419 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.datasink" in "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink".
# 190404-14:39:10,424 nipype.workflow DEBUG:
# 	 [Node] Directory not found "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink".
# 190404-14:39:10,429 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink
# 190404-14:39:10,433 nipype.utils DEBUG:
# 	 Creating directory /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink
# 190404-14:39:10,439 nipype.utils DEBUG:
# 	 Creating directory /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink/_report
# 190404-14:39:10,443 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink/_report/report.rst"
# 190404-14:39:10,451 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 190404-14:39:10,457 nipype.interface DEBUG:
# 	 key: test files: ['pe1_pe0_merged.nii.gz', 'pe1_1vol.nii.gz']
# 190404-14:39:10,465 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink/_0x73d00890348bf5460dadc75a079fbe0f_unfinished.json;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink/_inputs.pklz;/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink/_node.pklz
# 190404-14:39:10,470 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink/_report
# 190404-14:39:10,475 nipype.workflow DEBUG:
# 	 Removing files:
# 190404-14:39:10,480 nipype.workflow DEBUG:
# 	 saved results in /Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink/result_datasink.pklz
# 190404-14:39:10,485 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow_LS/preproc_flow/_subject_id_001-prac/datasink/_report/report.rst"
# 190404-14:39:10,490 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190404-14:39:10,495 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.datasink".
# 190404-14:39:12,368 nipype.workflow DEBUG:
# 	 Progress: 3 jobs, 2/1/0 (done/running/ready), 1/0 (pending_tasks/waiting).
# 190404-14:39:12,370 nipype.workflow INFO:
# 	 [Job 2] Completed (preproc_flow.datasink).
# 190404-14:39:12,372 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190404-14:39:12,373 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190404-14:39:12,374 nipype.workflow DEBUG:
# 	 No tasks are being run, and no jobs can be submitted to the queue. Potential deadlock

# %%
fslroi1 = Node(fsl.ExtractROI(t_min = 0,
                             t_size = 1,
                             roi_file = 'pe1_roi.nii.gz'),
                 name = 'fslroi1')

fslroi2 = Node(fsl.ExtractROI(t_min = 0,
                              t_size = 1,
                              roi_file = 'pe0_roi.nii.gz'),
                 name = 'fslroi2')

def conc_files(in_file1, in_file2):
    return [in_file1, in_file2]

conc_int = JoinNode(Function(input_names=['in_file1', 'infile2'],
                         output_names=['file_list'],
                        function = conc_files),
               name='conc_int')

merge = Node(fsl.Merge(dimension = 't',
                      merged_file = 'pe1_pe0_merged.nii.gz'),
            name='merge')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-027fa18b55f2> in <module>
#      16                          output_names=['file_list'],
#      17                         function = conc_files),
# ---> 18                name='conc_int')
#      19
#      20 merge = Node(fsl.Merge(dimension = 't',
#
# TypeError: __init__() missing 1 required positional argument: 'joinsource'
