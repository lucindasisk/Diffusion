# %%
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber 
from nipype.interfaces.utility import IdentityInterface, Function    
from nipype.pipeline.engine import Node, Workflow, JoinNode, MapNode
from nipype.interfaces import fsl
from nipype.interfaces import freesurfer as fsr
from nipype.interfaces import mrtrix3 as mtx
from pandas import Series, read_csv, to_numeric
from glob import glob
from os.path import abspath, expanduser, join
from os import chdir, remove, getcwd
from nipype import config, logging
from datetime import date
today = str(date.today())
config.enable_debug_mode()

# %%
#Set variables
subject_list = ['sub-A200', 'sub-A201']

user = expanduser('~')
home = join(user,'Box/CANDLab/DATA')

if user == '/Users/lucindasisk':
    workflow_dir = join(home, 'workflow_LS')
    data_dir = join(home, 'DataDir_LS')

# %%
#Setup Datasink, Infosource, Selectfiles

datasink = Node(DataSink(base_directory = data_dir),
                   name='datasink')

#Set infosource iterables
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

#SelectFiles
template = dict(t1 = join(home,'{subject_id}/anat/{subject_id}_ses-shapesV1_T1w.nii.gz'),
                dti = join(home,'{subject_id}/dwi/{subject_id}_ses-shapesV1_dwi.nii.gz'),
                bval = join(home,'{subject_id}/dwi/{subject_id}_ses-shapesV1_dwi.bval'),
                bvec = join(home,'{subject_id}/dwi/{subject_id}_ses-shapesV1_dwi.bvec'),
                fmappa = join(home,'{subject_id}/fmap/{subject_id}_ses-shapesV1_acq-dwi_dir-PA_epi.nii.gz'),  
                fmapap = join(home,'{subject_id}/fmap/{subject_id}_ses-shapesV1_acq-dwi_dir-AP_epi.nii.gz'),
                aps = join(home, 'shapes_acqparams.txt'),
                index = join(home, 'shapes_index.txt')
               )#,
               # index = join(home, 'index.txt'),
               # aps = join(home, 'acqparams.txt'),
               # tryxfm = join(home, 'transform.txt'))

sf = Node(SelectFiles(template, 
                      base_directory = home),
          name = 'sf')

# %%
#Merge AP/PA encoding direction fieldmaps
def create_merged_files(ap, pa):
    from nipype.interfaces import fsl
    from os.path import abspath
    merge = fsl.Merge(in_files= [ap, pa],
                      dimension = 't', merged_file = 'AP_PA_merged.nii.gz').run()
    merged_file = abspath('AP_PA_merged.nii.gz')
    return merged_file

create_merge = Node(Function(input_names=['ap', 'pa'],
                             output_names=['merged_file'],
                             function = create_merged_files),
                    name='create_merge')

# %%
#Resample T1w to same voxel dimensions as DTI to avoid data interpolation (1.714286 x 1.714286 x 1.700001) .  
resampt1 = Node(fsr.Resample(voxel_size = (1.714286, 1.714286, 1.700001)),
               name='resampT1')

#Drop bottom slice (S/I) to create even # of slices
drop = Node(fsl.ExtractROI(x_min=0, x_size=140,
                           y_min=0, y_size=140,
                           z_min=1, z_size=80),
           name='drop')

#drop bottom slice of DTI file
drop2 = drop.clone(name='drop2')

#Denoise DWI data susing local PCA correction 
denoise = Node(mtx.DWIDenoise(),
              name='denoise')

#Run topup on merged files from pe1 and pe0
topup = Node(fsl.TOPUP(config = 'b02b0.cnf',
                       out_corrected = 'ap_pa_topup.nii.gz'),
            name = 'topup')

#Select b0 image for registration
fslroi = Node(fsl.ExtractROI(t_min = 0, 
                             t_size = 1, 
                             roi_file = 'b0_img.nii.gz'),
              name = 'fslroi')

#Reorient topup b0 image to std
reorient1 = Node(fsl.Reorient2Std(output_type = 'NIFTI_GZ'),
                    name = 'reorient1')

#Register b0 to T1
register1 = Node(fsl.FLIRT(out_matrix_file = 'b0toT1_reorient_reg.mat',
                          output_type = 'NIFTI_GZ'),
                    name = 'register1')

#apply topup from merged file to rest of pe0 scan
apptop = Node(fsl.ApplyTOPUP(method='jac',
                            in_index=[2]),
             name = 'apptop')

#Skullstrip the T1w image
stripT1 = Node(fsl.BET(mask = True,
                       out_file = 'T1_stripped_anat.nii.gz'),
              name = 'stripT1')

#Reorient DTI data to standard orientation
reorient2 = Node(fsl.Reorient2Std(output_type = 'NIFTI_GZ'),
                    name = 'reorient2')

#Flirt node to resample DTI data to same dimensions as T1
register2 = Node(fsl.FLIRT(output_type = 'NIFTI_GZ',
                          apply_xfm=True),
                    name = 'register2')

#FSL Eddy correction to remove eddy current distortion
eddy = Node(fsl.Eddy(is_shelled = True),
           name = 'eddy')

# %%
def create_bids(t1, dti, bval, bvec, filepath):
    import os
    import shutil as st

# %%
preproc_flow = Workflow(name = 'preproc_flow')
preproc_flow.connect([(infosource, sf, [('subject_id','subject_id')]),
                      #Select AP and PA encoded fieldmaps; merge niftis
                      (sf, create_merge, [('fmapap', 'ap'),
                                         ('fmappa', 'pa')]),
                      #Drop bottom slice of nifi (had odd # slices)
                      (create_merge, drop, [('merged_file', 'in_file')]),
                      #Run topop across merged niftis
                      (drop, topup, [('roi_file', 'in_file')]),
                      (sf, topup, [('aps','encoding_file')]),
                      (topup, datasink,[('out_corrected', '1_Check_Unwarped.@par')]),
                      #Extract b0 image from nifti with topup applied
                      (topup, fslroi, [('out_corrected', 'in_file')]),
                      #Reorient b0 to standard
                      (fslroi, reorient1, [('roi_file', 'in_file')]),
                      #Register reoriented b0 to T1
                      (sf, register1, [('t1', 'reference')]),
                      (reorient1, register1, [('out_file', 'in_file')]),
                      (register1, datasink, [('out_file', '1_Check_Unwarped.@par.@par')]),
                      #Apply transform generated in topup to DTI
                      (topup, apptop, [('out_fieldcoef', 'in_topup_fieldcoef'),
                                       ('out_movpar', 'in_topup_movpar')]),
                      #Drop bottom slice from DTI nifti
                      (sf, drop2, [('dti', 'in_file')]),
                      (drop2, denoise, [('roi_file', 'in_file')]),
                      (denoise, datasink, [('out_file', '1_Check_Unwarped.@par.@par.@par'),
                                          ('noise','1_Check_Unwarped.@par.@par.@par.@par')]),
                      (denoise, apptop, [('out_file', 'in_files')]),
                      (sf, apptop, [('aps', 'encoding_file')]),
                      (apptop, datasink, [('out_corrected', '1_Check_Unwarped.@par.@par.@par.@par.@par')]),
                      #Resample T1w to same voxel dimensions as DTI
                      (sf,  resampt1, [('t1', 'in_file')]),
                      (resampt1, stripT1, [('resampled_file','in_file')]),
                      #Skull strip T1w, save stripped anat and mask
                      (stripT1, datasink, [('mask_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par'),
                                          ('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par.@par')]),
                      #reorient DTI file with topup applied to standard
                      (apptop, reorient2, [('out_corrected','in_file')]),
                      (reorient2, datasink, [('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par.@par.@par')]),
                      #Register DTI to skullstripped, resampled T1w 
                      (reorient2, register2, [('out_file','in_file')]),
                      (stripT1, register2, [('out_file','reference')]),
                      #use xfm from b0 registration from T1 to apply to DTI nifti
                      (register1, register2, [('out_matrix_file', 'in_matrix_file')]),
                      (register2, datasink, [('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par.@par.@par.@par')]),  
                      #Run eddy correction
                      (sf, eddy, [('index', 'in_index'),
                                 ('bvec', 'in_bvec'),
                                 ('bval', 'in_bval'),
                                 ('aps', 'in_acqp')]),
                      (stripT1, eddy, [('mask_file', 'in_mask')]),
                      (register2, eddy, [('out_file','in_file')]),
                      (eddy, datasink,[('out_corrected','2_Eddy_Corrected'),
                                       ('out_rotated_bvecs','2_Eddy_Corrected.@par'),
                                       ('out_movement_rms','2_Eddy_Corrected.@par.@par'),
                                       ('out_outlier_report','2_Eddy_Corrected.@par.@par.@par')])
                     ])
preproc_flow.base_dir = workflow_dir
preproc_flow.write_graph(graph2use = 'flat')
preproc = preproc_flow.run('MultiProc', plugin_args={'n_procs': 4})
# Out:
# 190516-23:08:08,253 nipype.workflow DEBUG:
# 	 (preproc_flow.infosource, preproc_flow.sf): No edge data
# 190516-23:08:08,254 nipype.workflow DEBUG:
# 	 (preproc_flow.infosource, preproc_flow.sf): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 190516-23:08:08,255 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.create_merge): No edge data
# 190516-23:08:08,256 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.create_merge): new edge data: {'connect': [('fmapap', 'ap'), ('fmappa', 'pa')]}
# 190516-23:08:08,257 nipype.workflow DEBUG:
# 	 (preproc_flow.create_merge, preproc_flow.drop): No edge data
# 190516-23:08:08,257 nipype.workflow DEBUG:
# 	 (preproc_flow.create_merge, preproc_flow.drop): new edge data: {'connect': [('merged_file', 'in_file')]}
# 190516-23:08:08,259 nipype.workflow DEBUG:
# 	 (preproc_flow.drop, preproc_flow.topup): No edge data
# 190516-23:08:08,260 nipype.workflow DEBUG:
# 	 (preproc_flow.drop, preproc_flow.topup): new edge data: {'connect': [('roi_file', 'in_file')]}
# 190516-23:08:08,260 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.topup): No edge data
# 190516-23:08:08,261 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.topup): new edge data: {'connect': [('aps', 'encoding_file')]}
# 190516-23:08:08,261 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.datasink): No edge data
# 190516-23:08:08,262 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.datasink): new edge data: {'connect': [('out_corrected', '1_Check_Unwarped.@par')]}
# 190516-23:08:08,262 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.fslroi): No edge data
# 190516-23:08:08,263 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.fslroi): new edge data: {'connect': [('out_corrected', 'in_file')]}
# 190516-23:08:08,263 nipype.workflow DEBUG:
# 	 (preproc_flow.fslroi, preproc_flow.reorient1): No edge data
# 190516-23:08:08,264 nipype.workflow DEBUG:
# 	 (preproc_flow.fslroi, preproc_flow.reorient1): new edge data: {'connect': [('roi_file', 'in_file')]}
# 190516-23:08:08,265 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.register1): No edge data
# 190516-23:08:08,266 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.register1): new edge data: {'connect': [('t1', 'reference')]}
# 190516-23:08:08,266 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient1, preproc_flow.register1): No edge data
# 190516-23:08:08,267 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient1, preproc_flow.register1): new edge data: {'connect': [('out_file', 'in_file')]}
# 190516-23:08:08,268 nipype.workflow DEBUG:
# 	 (preproc_flow.register1, preproc_flow.datasink): No edge data
# 190516-23:08:08,268 nipype.workflow DEBUG:
# 	 (preproc_flow.register1, preproc_flow.datasink): new edge data: {'connect': [('out_file', '1_Check_Unwarped.@par.@par')]}
# 190516-23:08:08,269 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.apptop): No edge data
# 190516-23:08:08,270 nipype.workflow DEBUG:
# 	 (preproc_flow.topup, preproc_flow.apptop): new edge data: {'connect': [('out_fieldcoef', 'in_topup_fieldcoef'), ('out_movpar', 'in_topup_movpar')]}
# 190516-23:08:08,270 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.drop2): No edge data
# 190516-23:08:08,271 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.drop2): new edge data: {'connect': [('dti', 'in_file')]}
# 190516-23:08:08,271 nipype.workflow DEBUG:
# 	 (preproc_flow.drop2, preproc_flow.denoise): No edge data
# 190516-23:08:08,272 nipype.workflow DEBUG:
# 	 (preproc_flow.drop2, preproc_flow.denoise): new edge data: {'connect': [('roi_file', 'in_file')]}
# 190516-23:08:08,273 nipype.workflow DEBUG:
# 	 (preproc_flow.denoise, preproc_flow.datasink): No edge data
# 190516-23:08:08,273 nipype.workflow DEBUG:
# 	 (preproc_flow.denoise, preproc_flow.datasink): new edge data: {'connect': [('out_file', '1_Check_Unwarped.@par.@par.@par')]}
# 190516-23:08:08,274 nipype.workflow DEBUG:
# 	 (preproc_flow.denoise, preproc_flow.apptop): No edge data
# 190516-23:08:08,274 nipype.workflow DEBUG:
# 	 (preproc_flow.denoise, preproc_flow.apptop): new edge data: {'connect': [('out_file', 'in_files')]}
# 190516-23:08:08,275 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.apptop): No edge data
# 190516-23:08:08,275 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.apptop): new edge data: {'connect': [('aps', 'encoding_file')]}
# 190516-23:08:08,276 nipype.workflow DEBUG:
# 	 (preproc_flow.apptop, preproc_flow.datasink): No edge data
# 190516-23:08:08,276 nipype.workflow DEBUG:
# 	 (preproc_flow.apptop, preproc_flow.datasink): new edge data: {'connect': [('out_corrected', '1_Check_Unwarped.@par.@par.@par.@par')]}
# 190516-23:08:08,277 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.resampT1): No edge data
# 190516-23:08:08,277 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.resampT1): new edge data: {'connect': [('t1', 'in_file')]}
# 190516-23:08:08,277 nipype.workflow DEBUG:
# 	 (preproc_flow.resampT1, preproc_flow.stripT1): No edge data
# 190516-23:08:08,278 nipype.workflow DEBUG:
# 	 (preproc_flow.resampT1, preproc_flow.stripT1): new edge data: {'connect': [('resampled_file', 'in_file')]}
# 190516-23:08:08,279 nipype.workflow DEBUG:
# 	 (preproc_flow.stripT1, preproc_flow.datasink): No edge data
# 190516-23:08:08,279 nipype.workflow DEBUG:
# 	 (preproc_flow.stripT1, preproc_flow.datasink): new edge data: {'connect': [('mask_file', '1_Check_Unwarped.@par.@par.@par.@par.@par'), ('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par')]}
# 190516-23:08:08,280 nipype.workflow DEBUG:
# 	 (preproc_flow.apptop, preproc_flow.reorient2): No edge data
# 190516-23:08:08,280 nipype.workflow DEBUG:
# 	 (preproc_flow.apptop, preproc_flow.reorient2): new edge data: {'connect': [('out_corrected', 'in_file')]}
# 190516-23:08:08,280 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient2, preproc_flow.datasink): No edge data
# 190516-23:08:08,281 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient2, preproc_flow.datasink): new edge data: {'connect': [('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par.@par')]}
# 190516-23:08:08,282 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient2, preproc_flow.register2): No edge data
# 190516-23:08:08,282 nipype.workflow DEBUG:
# 	 (preproc_flow.reorient2, preproc_flow.register2): new edge data: {'connect': [('out_file', 'in_file')]}
# 190516-23:08:08,282 nipype.workflow DEBUG:
# 	 (preproc_flow.stripT1, preproc_flow.register2): No edge data
# 190516-23:08:08,283 nipype.workflow DEBUG:
# 	 (preproc_flow.stripT1, preproc_flow.register2): new edge data: {'connect': [('out_file', 'reference')]}
# 190516-23:08:08,284 nipype.workflow DEBUG:
# 	 (preproc_flow.register1, preproc_flow.register2): No edge data
# 190516-23:08:08,284 nipype.workflow DEBUG:
# 	 (preproc_flow.register1, preproc_flow.register2): new edge data: {'connect': [('out_matrix_file', 'in_matrix_file')]}
# 190516-23:08:08,285 nipype.workflow DEBUG:
# 	 (preproc_flow.register2, preproc_flow.datasink): No edge data
# 190516-23:08:08,285 nipype.workflow DEBUG:
# 	 (preproc_flow.register2, preproc_flow.datasink): new edge data: {'connect': [('out_file', '1_Check_Unwarped.@par.@par.@par.@par.@par.@par.@par.@par')]}
# 190516-23:08:08,285 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.eddy): No edge data
# 190516-23:08:08,286 nipype.workflow DEBUG:
# 	 (preproc_flow.sf, preproc_flow.eddy): new edge data: {'connect': [('index', 'in_index'), ('bvec', 'in_bvec'), ('bval', 'in_bval'), ('aps', 'in_acqp')]}
# 190516-23:08:08,287 nipype.workflow DEBUG:
# 	 (preproc_flow.stripT1, preproc_flow.eddy): No edge data
# 190516-23:08:08,287 nipype.workflow DEBUG:
# 	 (preproc_flow.stripT1, preproc_flow.eddy): new edge data: {'connect': [('mask_file', 'in_mask')]}
# 190516-23:08:08,287 nipype.workflow DEBUG:
# 	 (preproc_flow.register2, preproc_flow.eddy): No edge data
# 190516-23:08:08,288 nipype.workflow DEBUG:
# 	 (preproc_flow.register2, preproc_flow.eddy): new edge data: {'connect': [('out_file', 'in_file')]}
# 190516-23:08:08,288 nipype.workflow DEBUG:
# 	 (preproc_flow.eddy, preproc_flow.datasink): No edge data
# 190516-23:08:08,289 nipype.workflow DEBUG:
# 	 (preproc_flow.eddy, preproc_flow.datasink): new edge data: {'connect': [('out_corrected', '2_Eddy_Corrected'), ('out_rotated_bvecs', '2_Eddy_Corrected.@par'), ('out_movement_rms', '2_Eddy_Corrected.@par.@par'), ('out_outlier_report', '2_Eddy_Corrected.@par.@par.@par')]}
# 190516-23:08:08,289 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: preproc_flow
# 190516-23:08:08,295 nipype.workflow DEBUG:
# 	 expanding workflow: preproc_flow
# 190516-23:08:08,297 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.infosource
# 190516-23:08:08,297 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.sf
# 190516-23:08:08,298 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.resampT1
# 190516-23:08:08,298 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.stripT1
# 190516-23:08:08,299 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.drop2
# 190516-23:08:08,299 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.denoise
# 190516-23:08:08,300 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.create_merge
# 190516-23:08:08,300 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.drop
# 190516-23:08:08,301 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.topup
# 190516-23:08:08,302 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.apptop
# 190516-23:08:08,302 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.reorient2
# 190516-23:08:08,303 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.fslroi
# 190516-23:08:08,304 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.reorient1
# 190516-23:08:08,304 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.register1
# 190516-23:08:08,304 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.register2
# 190516-23:08:08,305 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.eddy
# 190516-23:08:08,305 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.datasink
# 190516-23:08:08,306 nipype.workflow DEBUG:
# 	 finished expanding workflow: preproc_flow
# 190516-23:08:08,311 nipype.workflow DEBUG:
# 	 using input graph
# 190516-23:08:08,664 nipype.workflow DEBUG:
# 	 creating dot graph
# 190516-23:08:08,933 nipype.workflow INFO:
# 	 Generated workflow graph: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/graph.png (graph2use=flat, simple_form=True).
# 190516-23:08:08,966 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=4, mem_gb=28.80, cwd=/Users/lucindasisk/Dropbox/Github/Diffusion)
# 190516-23:08:08,969 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: preproc_flow
# 190516-23:08:08,977 nipype.workflow DEBUG:
# 	 expanding workflow: preproc_flow
# 190516-23:08:08,979 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.infosource
# 190516-23:08:08,979 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.sf
# 190516-23:08:08,980 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.resampT1
# 190516-23:08:08,980 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.stripT1
# 190516-23:08:08,981 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.drop2
# 190516-23:08:08,982 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.denoise
# 190516-23:08:08,983 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.create_merge
# 190516-23:08:08,983 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.drop
# 190516-23:08:08,984 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.topup
# 190516-23:08:08,985 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.apptop
# 190516-23:08:08,985 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.reorient2
# 190516-23:08:08,986 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.fslroi
# 190516-23:08:08,987 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.reorient1
# 190516-23:08:08,987 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.register1
# 190516-23:08:08,988 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.register2
# 190516-23:08:08,989 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.eddy
# 190516-23:08:08,990 nipype.workflow DEBUG:
# 	 processing node: preproc_flow.datasink
# 190516-23:08:08,991 nipype.workflow DEBUG:
# 	 finished expanding workflow: preproc_flow
# 190516-23:08:08,992 nipype.workflow INFO:
# 	 Workflow preproc_flow settings: ['check', 'execution', 'logging', 'monitoring']
# 190516-23:08:08,999 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 190516-23:08:09,0 nipype.workflow DEBUG:
# 	 Detected iterable nodes [preproc_flow.infosource]
# 190516-23:08:09,1 nipype.workflow DEBUG:
# 	 Expanding the iterable node preproc_flow.infosource...
# 190516-23:08:09,2 nipype.workflow DEBUG:
# 	 node: preproc_flow.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x150e040d08>}
# 190516-23:08:09,3 nipype.workflow DEBUG:
# 	 ('subnodes:', [preproc_flow.infosource, preproc_flow.sf, preproc_flow.create_merge, preproc_flow.drop, preproc_flow.topup, preproc_flow.datasink, preproc_flow.fslroi, preproc_flow.reorient1, preproc_flow.register1, preproc_flow.register2, preproc_flow.eddy, preproc_flow.apptop, preproc_flow.reorient2, preproc_flow.drop2, preproc_flow.denoise, preproc_flow.resampT1, preproc_flow.stripT1])
# 190516-23:08:09,10 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = sub-A200
# 190516-23:08:09,11 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_sub-A200
# 190516-23:08:09,17 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = sub-A201
# 190516-23:08:09,18 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_sub-A201
# 190516-23:08:09,19 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 190516-23:08:09,20 nipype.workflow DEBUG:
# 	 [Node] sf - setting input subject_id = sub-A201
# 190516-23:08:09,21 nipype.workflow DEBUG:
# 	 Removed the identity node preproc_flow.infosource from the graph.
# 190516-23:08:09,22 nipype.workflow DEBUG:
# 	 [Node] sf - setting input subject_id = sub-A200
# 190516-23:08:09,22 nipype.workflow DEBUG:
# 	 Removed the identity node preproc_flow.infosource from the graph.
# 190516-23:08:09,70 nipype.workflow DEBUG:
# 	 Performing depth first search
# 190516-23:08:09,90 nipype.workflow INFO:
# 	 Running in parallel.
# 190516-23:08:09,93 nipype.workflow DEBUG:
# 	 Progress: 32 jobs, 0/0/2 (done/running/ready), 0/32 (pending_tasks/waiting).
# 190516-23:08:09,94 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190516-23:08:09,95 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190516-23:08:09,141 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.sf ID=0 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190516-23:08:09,141 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:09,145 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/Users/lucindasisk/Box/CANDLab/DATA'), ('force_lists', False), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', 'sub-A201')], 346a26e7a25c5637e0526bcb35626126, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_0x346a26e7a25c5637e0526bcb35626126.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_0x346a26e7a25c5637e0526bcb35626126.json']
# 190516-23:08:09,146 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.sf".
# 190516-23:08:09,147 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.sf" locally: cached=True, updated=True.
# 190516-23:08:09,164 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.sf (taskid=1).
# 190516-23:08:09,168 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.sf ID=16 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 190516-23:08:09,169 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:09,172 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/Users/lucindasisk/Box/CANDLab/DATA'), ('force_lists', False), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', 'sub-A200')], 679b7db42b50d265e332d9343d96d6a0, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_0x679b7db42b50d265e332d9343d96d6a0.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_0x679b7db42b50d265e332d9343d96d6a0.json']
# 190516-23:08:09,168 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.sf" in "/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf".190516-23:08:09,174 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.sf".
#
# 190516-23:08:09,175 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.sf" locally: cached=True, updated=True.
# 190516-23:08:09,178 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task preproc_flow.sf (taskid=2).
# 190516-23:08:09,177 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/Users/lucindasisk/Box/CANDLab/DATA'), ('force_lists', False), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', 'sub-A201')], 346a26e7a25c5637e0526bcb35626126, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_0x346a26e7a25c5637e0526bcb35626126.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_0x346a26e7a25c5637e0526bcb35626126.json']
# 190516-23:08:09,183 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.sf".
# 190516-23:08:09,182 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc_flow.sf" in "/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf".
# 190516-23:08:09,188 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "preproc_flow.sf"
# 190516-23:08:09,191 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/Users/lucindasisk/Box/CANDLab/DATA'), ('force_lists', False), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', 'sub-A200')], 679b7db42b50d265e332d9343d96d6a0, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_0x679b7db42b50d265e332d9343d96d6a0.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_0x679b7db42b50d265e332d9343d96d6a0.json']
# 190516-23:08:09,197 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf190516-23:08:09,197 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.sf".
#
# 190516-23:08:09,201 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "preproc_flow.sf"
# 190516-23:08:09,209 nipype.utils DEBUG:
# 	 Removing contents of /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf
# 190516-23:08:09,224 nipype.utils DEBUG:
# 	 Creating directory /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_report
# 190516-23:08:09,235 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_report/report.rst"
# 190516-23:08:09,249 nipype.utils DEBUG:
# 	 Creating directory /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_report
# 190516-23:08:09,258 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_report/report.rst"
# 190516-23:08:11,97 nipype.workflow DEBUG:
# 	 Progress: 32 jobs, 0/2/0 (done/running/ready), 2/30 (pending_tasks/waiting).
# 190516-23:08:11,98 nipype.workflow DEBUG:
# 	 Tasks currently running: 2. Pending: 2.
# 190516-23:08:11,100 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 28.40/28.80, Free processors: 2/4.
#                      Currently running:
#                        * preproc_flow.sf
#                        * preproc_flow.sf
# 190516-23:08:21,304 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190516-23:08:21,326 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190516-23:08:21,346 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Box/CANDLab/DATA/sub-A201/anat/sub-A201_ses-shapesV1_T1w.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/sub-A201/dwi/sub-A201_ses-shapesV1_dwi.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/sub-A201/dwi/sub-A201_ses-shapesV1_dwi.bval;/Users/lucindasisk/Box/CANDLab/DATA/sub-A201/dwi/sub-A201_ses-shapesV1_dwi.bvec;/Users/lucindasisk/Box/CANDLab/DATA/sub-A201/fmap/sub-A201_ses-shapesV1_acq-dwi_dir-PA_epi.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/sub-A201/fmap/sub-A201_ses-shapesV1_acq-dwi_dir-AP_epi.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/shapes_acqparams.txt;/Users/lucindasisk/Box/CANDLab/DATA/shapes_index.txt;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_0x346a26e7a25c5637e0526bcb35626126_unfinished.json;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_inputs.pklz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_node.pklz
# 190516-23:08:21,352 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_report
# 190516-23:08:21,355 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Box/CANDLab/DATA/sub-A200/anat/sub-A200_ses-shapesV1_T1w.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/sub-A200/dwi/sub-A200_ses-shapesV1_dwi.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/sub-A200/dwi/sub-A200_ses-shapesV1_dwi.bval;/Users/lucindasisk/Box/CANDLab/DATA/sub-A200/dwi/sub-A200_ses-shapesV1_dwi.bvec;/Users/lucindasisk/Box/CANDLab/DATA/sub-A200/fmap/sub-A200_ses-shapesV1_acq-dwi_dir-PA_epi.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/sub-A200/fmap/sub-A200_ses-shapesV1_acq-dwi_dir-AP_epi.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/shapes_acqparams.txt;/Users/lucindasisk/Box/CANDLab/DATA/shapes_index.txt;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_0x679b7db42b50d265e332d9343d96d6a0_unfinished.json;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_inputs.pklz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_node.pklz
# 190516-23:08:21,357 nipype.workflow DEBUG:
# 	 Removing files:
# 190516-23:08:21,359 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_report
# 190516-23:08:21,364 nipype.workflow DEBUG:
# 	 Removing files:
# 190516-23:08:21,376 nipype.workflow DEBUG:
# 	 saved results in /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:21,388 nipype.workflow DEBUG:
# 	 saved results in /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/result_sf.pklz
# 190516-23:08:21,391 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/_report/report.rst"
# 190516-23:08:21,398 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/_report/report.rst"
# 190516-23:08:21,407 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190516-23:08:21,414 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190516-23:08:21,421 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.sf".
# 190516-23:08:21,428 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.sf".
# 190516-23:08:23,105 nipype.workflow INFO:
# 	 [Job 0] Completed (preproc_flow.sf).
# 190516-23:08:23,107 nipype.workflow INFO:
# 	 [Job 16] Completed (preproc_flow.sf).
# 190516-23:08:23,109 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190516-23:08:23,110 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190516-23:08:23,145 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.resampT1 ID=1 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190516-23:08:23,146 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:23,147 nipype.workflow DEBUG:
# 	 input: in_file
# 190516-23:08:23,147 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:23,148 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:23,154 nipype.workflow DEBUG:
# 	 output: t1
# 190516-23:08:23,155 nipype.workflow DEBUG:
# 	 [Node] resampT1 - setting input in_file = /Users/lucindasisk/Box/CANDLab/DATA/sub-A201/anat/sub-A201_ses-shapesV1_T1w.nii.gz
# 190516-23:08:23,158 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/lucindasisk/Box/CANDLab/DATA/sub-A201/anat/sub-A201_ses-shapesV1_T1w.nii.gz', '60314f524e2c3160a988bb9316d537fd')), ('subjects_dir', '/Applications/freesurfer/subjects'), ('voxel_size', ('1.7142860000', '1.7142860000', '1.7000010000'))], 730b18ff95fb712574cd335ac67a6f03, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/resampT1/_0x730b18ff95fb712574cd335ac67a6f03.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/resampT1/_0x730b18ff95fb712574cd335ac67a6f03.json']
# 190516-23:08:23,159 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.resampT1".
# 190516-23:08:23,159 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.resampT1" locally: cached=True, updated=True.
# 190516-23:08:23,160 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.resampT1 with ID 1.
# 190516-23:08:23,160 nipype.workflow INFO:
# 	 [Job 1] Cached (preproc_flow.resampT1).
# 190516-23:08:23,162 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.drop2 ID=3 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 190516-23:08:23,162 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:23,163 nipype.workflow DEBUG:
# 	 input: in_file
# 190516-23:08:23,164 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:23,164 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:23,168 nipype.workflow DEBUG:
# 	 output: dti
# 190516-23:08:23,169 nipype.workflow DEBUG:
# 	 [Node] drop2 - setting input in_file = /Users/lucindasisk/Box/CANDLab/DATA/sub-A201/dwi/sub-A201_ses-shapesV1_dwi.nii.gz
# 190516-23:08:23,172 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/lucindasisk/Box/CANDLab/DATA/sub-A201/dwi/sub-A201_ses-shapesV1_dwi.nii.gz', 'c746fe8a9abba78d484149ab92147ecf')), ('output_type', 'NIFTI_GZ'), ('x_min', 0), ('x_size', 140), ('y_min', 0), ('y_size', 140), ('z_min', 1), ('z_size', 80)], 4b0ea83f6b94d49cd5db669b6d1d7e80, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop2/_0x4b0ea83f6b94d49cd5db669b6d1d7e80.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop2/_0x4b0ea83f6b94d49cd5db669b6d1d7e80.json']
# 190516-23:08:23,172 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.drop2".
# 190516-23:08:23,173 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.drop2" locally: cached=True, updated=True.
# 190516-23:08:23,173 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.drop2 with ID 3.
# 190516-23:08:23,174 nipype.workflow INFO:
# 	 [Job 3] Cached (preproc_flow.drop2).
# 190516-23:08:23,175 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.create_merge ID=5 (0.20GB, 1 threads). Free: 28.20GB, 1 threads.
# 190516-23:08:23,176 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:23,177 nipype.workflow DEBUG:
# 	 input: ap
# 190516-23:08:23,177 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:23,178 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:23,182 nipype.workflow DEBUG:
# 	 output: fmapap
# 190516-23:08:23,182 nipype.workflow DEBUG:
# 	 [Node] create_merge - setting input ap = /Users/lucindasisk/Box/CANDLab/DATA/sub-A201/fmap/sub-A201_ses-shapesV1_acq-dwi_dir-AP_epi.nii.gz
# 190516-23:08:23,183 nipype.workflow DEBUG:
# 	 input: pa
# 190516-23:08:23,184 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:23,184 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:23,188 nipype.workflow DEBUG:
# 	 output: fmappa
# 190516-23:08:23,189 nipype.workflow DEBUG:
# 	 [Node] create_merge - setting input pa = /Users/lucindasisk/Box/CANDLab/DATA/sub-A201/fmap/sub-A201_ses-shapesV1_acq-dwi_dir-PA_epi.nii.gz
# 190516-23:08:23,193 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('ap', ('/Users/lucindasisk/Box/CANDLab/DATA/sub-A201/fmap/sub-A201_ses-shapesV1_acq-dwi_dir-AP_epi.nii.gz', '79595d7e66d699a6886cfe35c35e3cbd')), ('function_str', "def create_merged_files(ap, pa):\n    from nipype.interfaces import fsl\n    from os.path import abspath\n    merge = fsl.Merge(in_files= [ap, pa],\n                      dimension = 't', merged_file = 'AP_PA_merged.nii.gz').run()\n    merged_file = abspath('AP_PA_merged.nii.gz')\n    return merged_file\n"), ('pa', ('/Users/lucindasisk/Box/CANDLab/DATA/sub-A201/fmap/sub-A201_ses-shapesV1_acq-dwi_dir-PA_epi.nii.gz', 'b5f2421456d69ecc3c00b7f8d1ef5e20'))], 12e66908ccfaf85ce7d6ed7bc54e019f, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/create_merge/_0x12e66908ccfaf85ce7d6ed7bc54e019f.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/create_merge/_0x12e66908ccfaf85ce7d6ed7bc54e019f.json']
# 190516-23:08:23,193 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.create_merge".
# 190516-23:08:23,194 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.create_merge" locally: cached=True, updated=True.
# 190516-23:08:23,194 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.create_merge with ID 5.
# 190516-23:08:23,195 nipype.workflow INFO:
# 	 [Job 5] Cached (preproc_flow.create_merge).
# 190516-23:08:23,196 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.resampT1 ID=17 (0.20GB, 1 threads). Free: 28.00GB, 0 threads.
# 190516-23:08:23,197 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:23,198 nipype.workflow DEBUG:
# 	 input: in_file
# 190516-23:08:23,198 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/result_sf.pklz
# 190516-23:08:23,199 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/result_sf.pklz
# 190516-23:08:23,203 nipype.workflow DEBUG:
# 	 output: t1
# 190516-23:08:23,204 nipype.workflow DEBUG:
# 	 [Node] resampT1 - setting input in_file = /Users/lucindasisk/Box/CANDLab/DATA/sub-A200/anat/sub-A200_ses-shapesV1_T1w.nii.gz
# 190516-23:08:23,207 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/lucindasisk/Box/CANDLab/DATA/sub-A200/anat/sub-A200_ses-shapesV1_T1w.nii.gz', '6c639f0981efb8c8421536b32ec27e0e')), ('subjects_dir', '/Applications/freesurfer/subjects'), ('voxel_size', ('1.7142860000', '1.7142860000', '1.7000010000'))], 4d0f81c914b9ff121d729ded497559bc, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/resampT1/_0x4d0f81c914b9ff121d729ded497559bc.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/resampT1/_0x4d0f81c914b9ff121d729ded497559bc.json']
# 190516-23:08:23,207 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.resampT1".
# 190516-23:08:23,208 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.resampT1" locally: cached=True, updated=True.
# 190516-23:08:23,208 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.resampT1 with ID 17.
# 190516-23:08:23,209 nipype.workflow INFO:
# 	 [Job 17] Cached (preproc_flow.resampT1).
# 190516-23:08:23,210 nipype.workflow DEBUG:
# 	 Cannot allocate job 19 (0.20GB, 1 threads).
# 190516-23:08:23,211 nipype.workflow DEBUG:
# 	 Cannot allocate job 21 (0.20GB, 1 threads).
# 190516-23:08:25,105 nipype.workflow DEBUG:
# 	 Progress: 32 jobs, 6/0/6 (done/running/ready), 0/26 (pending_tasks/waiting).
# 190516-23:08:25,106 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190516-23:08:25,141 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.stripT1 ID=2 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190516-23:08:25,142 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:25,142 nipype.workflow DEBUG:
# 	 input: in_file
# 190516-23:08:25,143 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/resampT1/result_resampT1.pklz
# 190516-23:08:25,143 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/resampT1/result_resampT1.pklz
# 190516-23:08:25,148 nipype.workflow DEBUG:
# 	 output: resampled_file
# 190516-23:08:25,149 nipype.workflow DEBUG:
# 	 [Node] stripT1 - setting input in_file = /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/resampT1/sub-A201_ses-shapesV1_T1w_resample.nii.gz
# 190516-23:08:25,152 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/resampT1/sub-A201_ses-shapesV1_T1w_resample.nii.gz', '11e255f089efdc486414393145415fa6')), ('mask', True), ('out_file', 'T1_stripped_anat.nii.gz'), ('output_type', 'NIFTI_GZ')], 7303a1ccaf8cb5b7b2191c2b738223ca, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/stripT1/_0x7303a1ccaf8cb5b7b2191c2b738223ca.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/stripT1/_0x7303a1ccaf8cb5b7b2191c2b738223ca.json']
# 190516-23:08:25,153 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.stripT1".
# 190516-23:08:25,154 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.stripT1" locally: cached=True, updated=True.
# 190516-23:08:25,154 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.stripT1 with ID 2.
# 190516-23:08:25,155 nipype.workflow INFO:
# 	 [Job 2] Cached (preproc_flow.stripT1).
# 190516-23:08:25,156 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.denoise ID=4 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 190516-23:08:25,157 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:25,157 nipype.workflow DEBUG:
# 	 input: in_file
# 190516-23:08:25,158 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop2/result_drop2.pklz
# 190516-23:08:25,158 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop2/result_drop2.pklz
# 190516-23:08:25,163 nipype.workflow DEBUG:
# 	 output: roi_file
# 190516-23:08:25,164 nipype.workflow DEBUG:
# 	 [Node] denoise - setting input in_file = /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop2/sub-A201_ses-shapesV1_dwi_roi.nii.gz
# 190516-23:08:25,166 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop2/sub-A201_ses-shapesV1_dwi_roi.nii.gz', 'b85c8957f46a254d75538e8ebe465873'))], 69360209adc33c03c8728de9832b29e6, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/denoise/_0x69360209adc33c03c8728de9832b29e6.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/denoise/_0x69360209adc33c03c8728de9832b29e6.json']
# 190516-23:08:25,167 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.denoise".
# 190516-23:08:25,167 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.denoise" locally: cached=True, updated=True.
# 190516-23:08:25,168 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.denoise with ID 4.
# 190516-23:08:25,168 nipype.workflow INFO:
# 	 [Job 4] Cached (preproc_flow.denoise).
# 190516-23:08:25,170 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.drop ID=6 (0.20GB, 1 threads). Free: 28.20GB, 1 threads.
# 190516-23:08:25,170 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:25,171 nipype.workflow DEBUG:
# 	 input: in_file
# 190516-23:08:25,171 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/create_merge/result_create_merge.pklz
# 190516-23:08:25,172 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/create_merge/result_create_merge.pklz
# 190516-23:08:25,177 nipype.workflow DEBUG:
# 	 output: merged_file
# 190516-23:08:25,177 nipype.workflow DEBUG:
# 	 [Node] drop - setting input in_file = /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/create_merge/AP_PA_merged.nii.gz
# 190516-23:08:25,181 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/create_merge/AP_PA_merged.nii.gz', '2157c45827f6e56e5306759446a34939')), ('output_type', 'NIFTI_GZ'), ('x_min', 0), ('x_size', 140), ('y_min', 0), ('y_size', 140), ('z_min', 1), ('z_size', 80)], 8624f2d3cc78839dde2c44d2369f0959, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop/_0x8624f2d3cc78839dde2c44d2369f0959.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop/_0x8624f2d3cc78839dde2c44d2369f0959.json']
# 190516-23:08:25,182 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.drop".
# 190516-23:08:25,182 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.drop" locally: cached=True, updated=True.
# 190516-23:08:25,183 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.drop with ID 6.
# 190516-23:08:25,183 nipype.workflow INFO:
# 	 [Job 6] Cached (preproc_flow.drop).
# 190516-23:08:25,185 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.stripT1 ID=18 (0.20GB, 1 threads). Free: 28.00GB, 0 threads.
# 190516-23:08:25,185 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:25,186 nipype.workflow DEBUG:
# 	 input: in_file
# 190516-23:08:25,186 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/resampT1/result_resampT1.pklz
# 190516-23:08:25,187 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/resampT1/result_resampT1.pklz
# 190516-23:08:25,191 nipype.workflow DEBUG:
# 	 output: resampled_file
# 190516-23:08:25,191 nipype.workflow DEBUG:
# 	 [Node] stripT1 - setting input in_file = /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/resampT1/sub-A200_ses-shapesV1_T1w_resample.nii.gz
# 190516-23:08:25,194 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/resampT1/sub-A200_ses-shapesV1_T1w_resample.nii.gz', '7f0a1389d205420bebef184d9567d83d')), ('mask', True), ('out_file', 'T1_stripped_anat.nii.gz'), ('output_type', 'NIFTI_GZ')], e1c1962338780e83282b5c668424dfd4, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/stripT1/_0xe1c1962338780e83282b5c668424dfd4.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/stripT1/_0xe1c1962338780e83282b5c668424dfd4.json']
# 190516-23:08:25,194 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.stripT1".
# 190516-23:08:25,195 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.stripT1" locally: cached=True, updated=True.
# 190516-23:08:25,195 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.stripT1 with ID 18.
# 190516-23:08:25,196 nipype.workflow INFO:
# 	 [Job 18] Cached (preproc_flow.stripT1).
# 190516-23:08:25,197 nipype.workflow DEBUG:
# 	 Cannot allocate job 19 (0.20GB, 1 threads).
# 190516-23:08:25,198 nipype.workflow DEBUG:
# 	 Cannot allocate job 21 (0.20GB, 1 threads).
# 190516-23:08:27,108 nipype.workflow DEBUG:
# 	 Progress: 32 jobs, 10/0/3 (done/running/ready), 0/22 (pending_tasks/waiting).
# 190516-23:08:27,109 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190516-23:08:27,111 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190516-23:08:27,145 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.topup ID=7 (0.20GB, 1 threads). Free: 28.60GB, 3 threads.
# 190516-23:08:27,146 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:27,146 nipype.workflow DEBUG:
# 	 input: encoding_file
# 190516-23:08:27,147 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:27,148 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/sf/result_sf.pklz
# 190516-23:08:27,152 nipype.workflow DEBUG:
# 	 output: aps
# 190516-23:08:27,153 nipype.workflow DEBUG:
# 	 [Node] topup - setting input encoding_file = /Users/lucindasisk/Box/CANDLab/DATA/shapes_acqparams.txt
# 190516-23:08:27,154 nipype.workflow DEBUG:
# 	 input: in_file
# 190516-23:08:27,155 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop/result_drop.pklz
# 190516-23:08:27,155 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop/result_drop.pklz
# 190516-23:08:27,160 nipype.workflow DEBUG:
# 	 output: roi_file
# 190516-23:08:27,160 nipype.workflow DEBUG:
# 	 [Node] topup - setting input in_file = /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop/AP_PA_merged_roi.nii.gz
# 190516-23:08:27,164 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('config', 'b02b0.cnf'), ('encoding_file', ('/Users/lucindasisk/Box/CANDLab/DATA/shapes_acqparams.txt', '7f324ec0b6adda348e6d5dce29acaca6')), ('in_file', ('/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/drop/AP_PA_merged_roi.nii.gz', 'b1d134bf66eab1f6f21f7e4dbdd3ab8a')), ('out_corrected', 'ap_pa_topup.nii.gz'), ('out_jac_prefix', 'jac'), ('out_mat_prefix', 'xfm'), ('out_warp_prefix', 'warpfield'), ('output_type', 'NIFTI_GZ')], 8b0ec7a41dee731a8ceb49ab5f486477, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/topup/_0x8b0ec7a41dee731a8ceb49ab5f486477.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A201/topup/_0x8b0ec7a41dee731a8ceb49ab5f486477.json']
# 190516-23:08:27,165 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.topup".
# 190516-23:08:27,165 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.topup" locally: cached=True, updated=True.
# 190516-23:08:27,166 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.topup with ID 7.
# 190516-23:08:27,166 nipype.workflow INFO:
# 	 [Job 7] Cached (preproc_flow.topup).
# 190516-23:08:27,168 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.drop2 ID=19 (0.20GB, 1 threads). Free: 28.40GB, 2 threads.
# 190516-23:08:27,168 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:27,169 nipype.workflow DEBUG:
# 	 input: in_file
# 190516-23:08:27,169 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/result_sf.pklz
# 190516-23:08:27,170 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/result_sf.pklz
# 190516-23:08:27,174 nipype.workflow DEBUG:
# 	 output: dti
# 190516-23:08:27,175 nipype.workflow DEBUG:
# 	 [Node] drop2 - setting input in_file = /Users/lucindasisk/Box/CANDLab/DATA/sub-A200/dwi/sub-A200_ses-shapesV1_dwi.nii.gz
# 190516-23:08:27,177 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/lucindasisk/Box/CANDLab/DATA/sub-A200/dwi/sub-A200_ses-shapesV1_dwi.nii.gz', '2abfe909b7a81d5c7209d868b2648fab')), ('output_type', 'NIFTI_GZ'), ('x_min', 0), ('x_size', 140), ('y_min', 0), ('y_size', 140), ('z_min', 1), ('z_size', 80)], 71add7dff833c41e14152c1cd0881b7b, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/drop2/_0x71add7dff833c41e14152c1cd0881b7b.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/drop2/_0x71add7dff833c41e14152c1cd0881b7b.json']
# 190516-23:08:27,178 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.drop2".
# 190516-23:08:27,179 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.drop2" locally: cached=True, updated=True.
# 190516-23:08:27,180 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.drop2 with ID 19.
# 190516-23:08:27,180 nipype.workflow INFO:
# 	 [Job 19] Cached (preproc_flow.drop2).
# 190516-23:08:27,182 nipype.workflow DEBUG:
# 	 Allocating preproc_flow.create_merge ID=21 (0.20GB, 1 threads). Free: 28.20GB, 1 threads.
# 190516-23:08:27,182 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190516-23:08:27,183 nipype.workflow DEBUG:
# 	 input: ap
# 190516-23:08:27,183 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/result_sf.pklz
# 190516-23:08:27,184 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/result_sf.pklz
# 190516-23:08:27,188 nipype.workflow DEBUG:
# 	 output: fmapap
# 190516-23:08:27,189 nipype.workflow DEBUG:
# 	 [Node] create_merge - setting input ap = /Users/lucindasisk/Box/CANDLab/DATA/sub-A200/fmap/sub-A200_ses-shapesV1_acq-dwi_dir-AP_epi.nii.gz
# 190516-23:08:27,189 nipype.workflow DEBUG:
# 	 input: pa
# 190516-23:08:27,190 nipype.workflow DEBUG:
# 	 results file: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/result_sf.pklz
# 190516-23:08:27,190 nipype.utils DEBUG:
# 	 Loading pkl: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/sf/result_sf.pklz
# 190516-23:08:27,194 nipype.workflow DEBUG:
# 	 output: fmappa
# 190516-23:08:27,194 nipype.workflow DEBUG:
# 	 [Node] create_merge - setting input pa = /Users/lucindasisk/Box/CANDLab/DATA/sub-A200/fmap/sub-A200_ses-shapesV1_acq-dwi_dir-PA_epi.nii.gz
# 190516-23:08:27,197 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('ap', ('/Users/lucindasisk/Box/CANDLab/DATA/sub-A200/fmap/sub-A200_ses-shapesV1_acq-dwi_dir-AP_epi.nii.gz', '2c49a53208bd95c4229788c5097de3f0')), ('function_str', "def create_merged_files(ap, pa):\n    from nipype.interfaces import fsl\n    from os.path import abspath\n    merge = fsl.Merge(in_files= [ap, pa],\n                      dimension = 't', merged_file = 'AP_PA_merged.nii.gz').run()\n    merged_file = abspath('AP_PA_merged.nii.gz')\n    return merged_file\n"), ('pa', ('/Users/lucindasisk/Box/CANDLab/DATA/sub-A200/fmap/sub-A200_ses-shapesV1_acq-dwi_dir-PA_epi.nii.gz', '61c72027650a1aeb628c81851baef03e'))], 65a17a9ac5b31e9111e235078c429a3d, /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/create_merge/_0x65a17a9ac5b31e9111e235078c429a3d.json, ['/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/create_merge/_0x65a17a9ac5b31e9111e235078c429a3d.json']
# 190516-23:08:27,198 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "preproc_flow.create_merge".
# 190516-23:08:27,198 nipype.workflow DEBUG:
# 	 Checking hash "preproc_flow.create_merge" locally: cached=True, updated=True.
# 190516-23:08:27,199 nipype.workflow DEBUG:
# 	 Skipping cached node preproc_flow.create_merge with ID 21.
# 190516-23:08:27,199 nipype.workflow INFO:
# 	 [Job 21] Cached (preproc_flow.create_merge).
# 190516-23:08:29,110 nipype.workflow DEBUG:
# 	 Progress: 32 jobs, 13/0/4 (done/running/ready), 0/19 (pending_tasks/waiting).
# 190516-23:08:29,111 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190516-23:08:29,113 nipype.workflow INFO:
# ...
# 190517-05:54:43,931 nipype.interface DEBUG:
# 	 key: 1_Check_Unwarped.@par.@par.@par.@par.@par.@par.@par files: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/reorient2/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz
# 190517-05:54:43,934 nipype.interface DEBUG:
# 	 copyfile: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/reorient2/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz
# 190517-05:54:43,937 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz
# 190517-05:54:45,332 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz already exists,3e19eb3985052d5ceef2622591f41689, copy:1
# 190517-05:54:46,693 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz already exists, not overwriting, copy:1
# 190517-05:54:46,697 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz
# 190517-05:54:48,28 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz already exists,3e19eb3985052d5ceef2622591f41689, copy:1
# 190517-05:54:49,353 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz already exists, not overwriting, copy:1
# 190517-05:54:49,358 nipype.interface DEBUG:
# 	 key: 1_Check_Unwarped.@par.@par.@par.@par.@par.@par.@par.@par files: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/register2/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz
# 190517-05:54:49,362 nipype.interface DEBUG:
# 	 copyfile: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/register2/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz
# 190517-05:54:49,366 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz
# 190517-05:54:49,948 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz already exists,c7aab3c42e61db5d6549b16d0bafa175, copy:1
# 190517-05:54:50,837 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz already exists, not overwriting, copy:1
# 190517-05:54:50,840 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz
# 190517-05:54:51,402 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz already exists,c7aab3c42e61db5d6549b16d0bafa175, copy:1
# 190517-05:54:52,260 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz already exists, not overwriting, copy:1
# 190517-05:54:52,264 nipype.interface DEBUG:
# 	 key: 2_Eddy_Corrected files: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.nii.gz
# 190517-05:54:52,269 nipype.interface DEBUG:
# 	 copyfile: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.nii.gz /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.nii.gz
# 190517-05:54:52,271 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.nii.gz
# 190517-05:54:52,275 nipype.utils DEBUG:
# 	 Linking File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.nii.gz->/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.nii.gz
# 190517-05:54:52,280 nipype.utils DEBUG:
# 	 Copying File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.nii.gz->/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.nii.gz
# 190517-05:54:54,86 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.nii.gz
# 190517-05:54:56,26 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.nii.gz already exists,5f85eeeaafd39350341e62188ac01389, copy:1
# 190517-05:54:58,9 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.nii.gz already exists, not overwriting, copy:1
# 190517-05:54:58,14 nipype.interface DEBUG:
# 	 key: 2_Eddy_Corrected.@par files: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_rotated_bvecs
# 190517-05:54:58,18 nipype.interface DEBUG:
# 	 copyfile: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_rotated_bvecs /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_rotated_bvecs
# 190517-05:54:58,21 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_rotated_bvecs
# 190517-05:54:58,24 nipype.utils DEBUG:
# 	 Linking File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_rotated_bvecs->/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_rotated_bvecs
# 190517-05:54:58,29 nipype.utils DEBUG:
# 	 Copying File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_rotated_bvecs->/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_rotated_bvecs
# 190517-05:54:58,53 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_rotated_bvecs
# 190517-05:54:58,64 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_rotated_bvecs already exists,8082611d1d3558c5ea2d963455be6c25, copy:1
# 190517-05:54:58,75 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_rotated_bvecs already exists, not overwriting, copy:1
# 190517-05:54:58,79 nipype.interface DEBUG:
# 	 key: 2_Eddy_Corrected.@par.@par files: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_movement_rms
# 190517-05:54:58,83 nipype.interface DEBUG:
# 	 copyfile: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_movement_rms /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_movement_rms
# 190517-05:54:58,86 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_movement_rms
# 190517-05:54:58,90 nipype.utils DEBUG:
# 	 Linking File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_movement_rms->/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_movement_rms
# 190517-05:54:58,95 nipype.utils DEBUG:
# 	 Copying File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_movement_rms->/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_movement_rms
# 190517-05:54:58,114 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_movement_rms
# 190517-05:54:58,126 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_movement_rms already exists,3f5c634941f9ab45a1814a34a6217bc7, copy:1
# 190517-05:54:58,135 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_movement_rms already exists, not overwriting, copy:1
# 190517-05:54:58,138 nipype.interface DEBUG:
# 	 key: 2_Eddy_Corrected.@par.@par.@par files: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_outlier_report
# 190517-05:54:58,142 nipype.interface DEBUG:
# 	 copyfile: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_outlier_report /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_outlier_report
# 190517-05:54:58,146 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_outlier_report
# 190517-05:54:58,149 nipype.utils DEBUG:
# 	 Linking File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_outlier_report->/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_outlier_report
# 190517-05:54:58,155 nipype.utils DEBUG:
# 	 Copying File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_outlier_report->/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_outlier_report
# 190517-05:54:58,171 nipype.utils DEBUG:
# 	 /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_outlier_report
# 190517-05:54:58,179 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_outlier_report already exists,ec38df405085695e8f15876e5fceb964, copy:1
# 190517-05:54:58,186 nipype.utils DEBUG:
# 	 File: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_outlier_report already exists, not overwriting, copy:1
# 190517-05:54:58,200 nipype.workflow DEBUG:
# 	 Needed files: /Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/ap_pa_topup.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/b0_img_reoriented_flirt.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/T1_stripped_anat_mask.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/T1_stripped_anat.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/1_Check_Unwarped/_subject_id_sub-A200/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_rotated_bvecs;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_movement_rms;/Users/lucindasisk/Box/CANDLab/DATA/DataDir_LS/2_Eddy_Corrected/_subject_id_sub-A200/eddy_corrected.eddy_outlier_report;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/topup/ap_pa_topup.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/register1/b0_img_reoriented_flirt.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/denoise/sub-A200_ses-shapesV1_dwi_roi_denoised.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/apptop/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/stripT1/T1_stripped_anat_mask.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/stripT1/T1_stripped_anat.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/reorient2/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/register2/sub-A200_ses-shapesV1_dwi_roi_denoised_corrected_reoriented_flirt.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.nii.gz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_rotated_bvecs;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_movement_rms;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/eddy/eddy_corrected.eddy_outlier_report;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/datasink/_0x69812cfdbe0d64e65710d956031c8da6_unfinished.json;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/datasink/_inputs.pklz;/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/datasink/_node.pklz
# 190517-05:54:58,202 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/datasink/_report
# 190517-05:54:58,205 nipype.workflow DEBUG:
# 	 Removing files:
# 190517-05:54:58,221 nipype.workflow DEBUG:
# 	 saved results in /Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/datasink/result_datasink.pklz
# 190517-05:54:58,227 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/lucindasisk/Box/CANDLab/DATA/workflow_LS/preproc_flow/_subject_id_sub-A200/datasink/_report/report.rst"
# 190517-05:54:58,236 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190517-05:54:58,246 nipype.workflow INFO:
# 	 [Node] Finished "preproc_flow.datasink".
# 190517-05:54:59,55 nipype.workflow INFO:
# 	 [Job 31] Completed (preproc_flow.datasink).
# 190517-05:54:59,56 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190517-05:54:59,58 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 4/4.
# 190517-05:54:59,58 nipype.workflow DEBUG:
# 	 No tasks are being run, and no jobs can be submitted to the queue. Potential deadlock
