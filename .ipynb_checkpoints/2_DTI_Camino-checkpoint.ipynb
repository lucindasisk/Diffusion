# %%
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber 
from nipype.interfaces.utility import IdentityInterface, Function    
from nipype.pipeline.engine import Node, Workflow
from nipype.interfaces import camino
import nipype.interfaces.camino2trackvis as cam2trk
import nipype.algorithms.misc as misc
from pandas import read_csv
from os.path import expanduser, join 
from nipype import config, logging
from datetime import date
today = str(date.today())
config.enable_debug_mode()
# Out:
# /usr/local/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/local/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
#Set variables
subject_list = ['001-prac']

user = expanduser('~')
home = join(user,'Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data')
if user == '/Users/lucindasisk':
    workflow_dir = join(home, 'workflow_LS')
    data_dir = join(home, 'DataDir_LS')
elif user == '/Users/myelin':
    workflow_dir = join(home, 'workflow')
    data_dir = join(home, 'DataDir')

i = read_csv(join(home, 'index.txt'), sep = ' ', header=None, dtype='Int64')
il = i.loc[0]
index = il.tolist()

# %%
#Setup Datasink, Infosource, Selectfiles

datasink = Node(DataSink(base_directory = data_dir),
                   name='datasink')

#Set infosource iterables
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

#SelectFiles
template = dict(dti_corr = join(data_dir, '2_Eddy_Corrected', '_subject_id_{subject_id}/eddy_corrected.nii.gz'),
                mask = join(data_dir, '1_Check_Unwarped/_subject_id_{subject_id}/T1_stripped_anat_mask.nii.gz'),
                stripT1 = join(data_dir, '1_Check_Unwarped/_subject_id_{subject_id}/T1_stripped_anat.nii.gz'),
                t1 = join(home, '{subject_id}/t1w.nii.gz'),
                bval = join(home, '{subject_id}/dti_pe0.bval'),
                bvec = join(data_dir, '2_Eddy_Corrected', '_subject_id_{subject_id}/eddy_corrected.eddy_rotated_bvecs'))   

sf = Node(SelectFiles(template, 
                      base_directory = home),
          name = 'sf')

# %%
### Nodes based on dMRI connectivity flow (https://github.com/nipy/nipype/blob/master/examples/dmri_connectivity.py)
def get_vox_dims(volume):
    import nibabel as nb
    from nipype.utils import NUMPY_MMAP
    if isinstance(volume, list):
        volume = volume[0]
    nii = nb.load(volume, mmap=NUMPY_MMAP)
    hdr = nii.header
    voxdims = hdr.get_zooms()
    out_vals = [float(voxdims[0]), float(voxdims[1]), float(voxdims[2])]
    return out_vals

#Node to extract voxel dimensions from eddy-corrected DTI
voxdims = Node(Function(input_names = ['volume'],
                       output_names = ['out_values'],
                       function = get_vox_dims),
              name = 'voxdims')

def get_data_dims(volume):
    import nibabel as nb
    from nipype.utils import NUMPY_MMAP
    if isinstance(volume, list):
        volume = volume[0]
    nii = nb.load(volume, mmap=NUMPY_MMAP)
    hdr = nii.header
    datadims = hdr.get_data_shape()
    out_vals = [int(datadims[0]), int(datadims[1]), int(datadims[2])]
    return out_vals

#Node to extract data dimensions from eddy-corrected DTI
datadims = Node(Function(input_names = ['volume'],
                       output_names = ['out_values'],
                       function = get_data_dims),
              name = 'datadims')

def get_affine(volume):
    import nibabel as nb
    from nipype.utils import NUMPY_MMAP
    nii = nb.load(volume, mmap=NUMPY_MMAP)
    out_file = nii.affine
    return out_file

#Node to extract affine matrix from eddy-corrected DTI
getaff = Node(Function(input_names = ['volume'],
                       output_names = ['out_file'],
                       function = get_affine),
              name = 'getaff')


#Convert bvals and bvecs to scheme files for Camino
fsl2scheme = Node(interface=camino.FSL2Scheme(usegradmod = True), 
                     name="fsl2scheme")

#Convert DTI nifti to voxel order for Camino
image2voxel = Node(interface=camino.Image2Voxel(), 
                      name="image2voxel")

#Fit diffusion tensors to voxel order data
dtifit = Node(interface=camino.DTIFit(), 
              name='dtifit')

#Generate LUT from scheme file and b0 SNR
dtlutgen = Node(interface=camino.DTLUTGen(), 
                name="dtlutgen")
dtlutgen.inputs.snr = 16.0
dtlutgen.inputs.inversion = 1

#Implement PICO probabilistic tractography
picopdfs = Node(interface=camino.PicoPDFs(), 
                name="picopdfs")
picopdfs.inputs.inputmodel = 'dt'

#Perform tractography with PICO (needs output from picopfs)
track = Node(interface=camino.TrackPICo(), 
             name="track")
track.inputs.iterations = 1

#Convert raw data to .trk format for use with TrackVis
camino2trackvis = Node(interface=cam2trk.Camino2Trackvis(), 
                       name="camino2trk")
camino2trackvis.inputs.min_length = 30
camino2trackvis.inputs.voxel_order = 'LAS'
trk2camino = Node(interface=cam2trk.Trackvis2Camino(), 
                  name="trk2camino")
 
#Generate FA and diffusivity trace maps + headers, then merge them into a single NII file
fa = Node(interface=camino.ComputeFractionalAnisotropy(), name='fa')
trace = Node(interface=camino.ComputeTensorTrace(), name='trace')
dteig = Node(interface=camino.ComputeEigensystem(), 
             name='dteig')
#Create header for FA
analyzeheader_fa = Node(interface=camino.AnalyzeHeader(), 
                        name='analyzeheader_fa')
analyzeheader_fa.inputs.datatype = 'double'

#Create header for Trace
analyzeheader_trace = Node(interface=camino.AnalyzeHeader(), 
                           name='analyzeheader_trace')
analyzeheader_trace.inputs.datatype = 'double'

#Create header for eigenvalues
analyzeheader_eig = Node(interface=camino.AnalyzeHeader(),
                         name='analyzeheader_eig')
analyzeheader_eig.inputs.datatype = 'double'

#Convert FA to NII
fa2nii = Node(interface=misc.CreateNifti(), name='fa2nii')

#Convert Trace to NII
trace2nii = fa2nii.clone("trace2nii")

#Convert Eig to NII
eig2nii = fa2nii.clone('eig2nii')

#Convert track data to nifti
niiconv = Node(interface=camino.DT2NIfTI(),
               name='niiconv')
niiconv_fa = niiconv.clone('niiconv_fa')

# %%
tract_flow = Workflow(name = 'tract_flow')
tract_flow.connect([(infosource, sf, [('subject_id','subject_id')]),
                    #Data Fitting
                    (sf, fsl2scheme, [('bvec', 'bvec_file'),
                                      ('bval','bval_file')]),
                    (sf, image2voxel, [('dti_corr', 'in_file')]),
                    #Create .Bdouble file using dtifit
                    (image2voxel, dtifit, [('voxel_order', 'in_file')]),
                    (fsl2scheme, dtifit, [('scheme', 'scheme_file')]),
                    (dtifit, datasink, [('tensor_fitted', '3_Tractography')]),
                    #Generage Lookup Tables (LUTs)
                    (fsl2scheme, dtlutgen, [('scheme', 'scheme_file')]),
                    (dtlutgen, picopdfs, [('dtLUT', 'luts')]),
                    #Run Pico fitting
                    (dtifit, picopdfs, [('tensor_fitted', 'in_file')]),
                    #Run tractography
                    (sf, track, [('mask', 'seed_file')]),
                    (picopdfs, track, [('pdfs','in_file')]),
                    (track, datasink, [('tracked', '3_Tractography.@par')]),
                    #convert fitted tract data to eigenvalues
                    (dtifit, dteig, [('tensor_fitted', 'in_file')]),
                    (dteig, datasink, [('eigen', '3_DTI_QC')]),
                    #Compute Eigenvalues & convert to NII --> Niiconv nodes don't work -- error ran out of voxels
                    (dteig, niiconv, [('eigen', 'in_file')]),
                    (sf, niiconv, [('dti_corr', 'header_file')]),
                    (niiconv, datasink, [('dt', '3_DTI_QC.@par')]),
                    #Compute FA
                    (sf, voxdims, [('dti_corr', 'volume')]),
                    (sf, datadims, [('dti_corr', 'volume')]),
                    (sf, getaff, [('dti_corr', 'volume')]),
                    (dtifit, fa, [('tensor_fitted','in_file')]),
                    (fa, datasink, [('fa', '3_Tractography.@par.@par')]),
                    (fa, analyzeheader_fa, [('fa','in_file')]),
                    (voxdims, analyzeheader_fa, [('out_values', 'voxel_dims')]),
                    (datadims, analyzeheader_fa, [('out_values', 'data_dims')]),
#                     (fa, fa2nii, [('fa','data_file')]),
#                     (getaff, fa2nii, [('out_file', 'affine')]),
#                     (analyzeheader_fa, fa2nii, [('header','header_file')]),
#                     (fa2nii, datasink, [('nifti_file', '3_Tractography.@par.@par.@par')]),
                    (fa, niiconv_fa, [('fa', 'in_file')]),
                    (sf, niiconv_fa, [('dti_corr', 'header_file')]),
                    (niiconv, datasink, [('dt', '3_Tractography.@par.@par.@par')]),
                    #Compute Trace
                    (dtifit, trace, [('tensor_fitted', 'in_file')]),
                    (trace, analyzeheader_trace, [('trace', 'in_file')]),
                    (voxdims, analyzeheader_trace, [('out_values', 'voxel_dims')]),
                    (datadims, analyzeheader_trace, [('out_values', 'data_dims')]),
                    (trace, trace2nii, [('trace', 'data_file')]),
                    (getaff, trace2nii, [('out_file', 'affine')]),
                    (analyzeheader_trace, trace2nii, [('header', 'header_file')]),
                    (trace2nii, datasink, [('nifti_file', '3_Tractography.@par.@par.@par.@par')]),
                    
                   ])
tract_flow.base_dir = workflow_dir
tract_flow.write_graph(graph2use = 'flat')
tract = tract_flow.run('MultiProc', plugin_args={'n_procs': 2})
# Out:
# 190426-17:48:28,799 nipype.workflow DEBUG:
# 	 (tract_flow.infosource, tract_flow.sf): No edge data
# 190426-17:48:28,800 nipype.workflow DEBUG:
# 	 (tract_flow.infosource, tract_flow.sf): new edge data: {'connect': [('subject_id', 'subject_id')]}
# 190426-17:48:28,801 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.fsl2scheme): No edge data
# 190426-17:48:28,802 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.fsl2scheme): new edge data: {'connect': [('bvec', 'bvec_file'), ('bval', 'bval_file')]}
# 190426-17:48:28,803 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.image2voxel): No edge data
# 190426-17:48:28,803 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.image2voxel): new edge data: {'connect': [('dti_corr', 'in_file')]}
# 190426-17:48:28,804 nipype.workflow DEBUG:
# 	 (tract_flow.image2voxel, tract_flow.dtifit): No edge data
# 190426-17:48:28,804 nipype.workflow DEBUG:
# 	 (tract_flow.image2voxel, tract_flow.dtifit): new edge data: {'connect': [('voxel_order', 'in_file')]}
# 190426-17:48:28,805 nipype.workflow DEBUG:
# 	 (tract_flow.fsl2scheme, tract_flow.dtifit): No edge data
# 190426-17:48:28,806 nipype.workflow DEBUG:
# 	 (tract_flow.fsl2scheme, tract_flow.dtifit): new edge data: {'connect': [('scheme', 'scheme_file')]}
# 190426-17:48:28,806 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.datasink): No edge data
# 190426-17:48:28,808 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.datasink): new edge data: {'connect': [('tensor_fitted', '3_Tractography')]}
# 190426-17:48:28,809 nipype.workflow DEBUG:
# 	 (tract_flow.fsl2scheme, tract_flow.dtlutgen): No edge data
# 190426-17:48:28,810 nipype.workflow DEBUG:
# 	 (tract_flow.fsl2scheme, tract_flow.dtlutgen): new edge data: {'connect': [('scheme', 'scheme_file')]}
# 190426-17:48:28,811 nipype.workflow DEBUG:
# 	 (tract_flow.dtlutgen, tract_flow.picopdfs): No edge data
# 190426-17:48:28,812 nipype.workflow DEBUG:
# 	 (tract_flow.dtlutgen, tract_flow.picopdfs): new edge data: {'connect': [('dtLUT', 'luts')]}
# 190426-17:48:28,812 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.picopdfs): No edge data
# 190426-17:48:28,813 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.picopdfs): new edge data: {'connect': [('tensor_fitted', 'in_file')]}
# 190426-17:48:28,814 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.track): No edge data
# 190426-17:48:28,815 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.track): new edge data: {'connect': [('mask', 'seed_file')]}
# 190426-17:48:28,816 nipype.workflow DEBUG:
# 	 (tract_flow.picopdfs, tract_flow.track): No edge data
# 190426-17:48:28,817 nipype.workflow DEBUG:
# 	 (tract_flow.picopdfs, tract_flow.track): new edge data: {'connect': [('pdfs', 'in_file')]}
# 190426-17:48:28,817 nipype.workflow DEBUG:
# 	 (tract_flow.track, tract_flow.datasink): No edge data
# 190426-17:48:28,818 nipype.workflow DEBUG:
# 	 (tract_flow.track, tract_flow.datasink): new edge data: {'connect': [('tracked', '3_Tractography.@par')]}
# 190426-17:48:28,818 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.dteig): No edge data
# 190426-17:48:28,819 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.dteig): new edge data: {'connect': [('tensor_fitted', 'in_file')]}
# 190426-17:48:28,820 nipype.workflow DEBUG:
# 	 (tract_flow.dteig, tract_flow.datasink): No edge data
# 190426-17:48:28,821 nipype.workflow DEBUG:
# 	 (tract_flow.dteig, tract_flow.datasink): new edge data: {'connect': [('eigen', '3_DTI_QC')]}
# 190426-17:48:28,821 nipype.workflow DEBUG:
# 	 (tract_flow.dteig, tract_flow.niiconv): No edge data
# 190426-17:48:28,822 nipype.workflow DEBUG:
# 	 (tract_flow.dteig, tract_flow.niiconv): new edge data: {'connect': [('eigen', 'in_file')]}
# 190426-17:48:28,822 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.niiconv): No edge data
# 190426-17:48:28,823 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.niiconv): new edge data: {'connect': [('dti_corr', 'header_file')]}
# 190426-17:48:28,823 nipype.workflow DEBUG:
# 	 (tract_flow.niiconv, tract_flow.datasink): No edge data
# 190426-17:48:28,824 nipype.workflow DEBUG:
# 	 (tract_flow.niiconv, tract_flow.datasink): new edge data: {'connect': [('dt', '3_DTI_QC.@par')]}
# 190426-17:48:28,824 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.voxdims): No edge data
# 190426-17:48:28,825 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.voxdims): new edge data: {'connect': [('dti_corr', 'volume')]}
# 190426-17:48:28,826 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.datadims): No edge data
# 190426-17:48:28,827 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.datadims): new edge data: {'connect': [('dti_corr', 'volume')]}
# 190426-17:48:28,828 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.getaff): No edge data
# 190426-17:48:28,828 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.getaff): new edge data: {'connect': [('dti_corr', 'volume')]}
# 190426-17:48:28,829 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.fa): No edge data
# 190426-17:48:28,830 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.fa): new edge data: {'connect': [('tensor_fitted', 'in_file')]}
# 190426-17:48:28,833 nipype.workflow DEBUG:
# 	 (tract_flow.fa, tract_flow.datasink): No edge data
# 190426-17:48:28,834 nipype.workflow DEBUG:
# 	 (tract_flow.fa, tract_flow.datasink): new edge data: {'connect': [('fa', '3_Tractography.@par.@par')]}
# 190426-17:48:28,834 nipype.workflow DEBUG:
# 	 (tract_flow.fa, tract_flow.analyzeheader_fa): No edge data
# 190426-17:48:28,835 nipype.workflow DEBUG:
# 	 (tract_flow.fa, tract_flow.analyzeheader_fa): new edge data: {'connect': [('fa', 'in_file')]}
# 190426-17:48:28,836 nipype.workflow DEBUG:
# 	 (tract_flow.voxdims, tract_flow.analyzeheader_fa): No edge data
# 190426-17:48:28,836 nipype.workflow DEBUG:
# 	 (tract_flow.voxdims, tract_flow.analyzeheader_fa): new edge data: {'connect': [('out_values', 'voxel_dims')]}
# 190426-17:48:28,838 nipype.workflow DEBUG:
# 	 (tract_flow.datadims, tract_flow.analyzeheader_fa): No edge data
# 190426-17:48:28,838 nipype.workflow DEBUG:
# 	 (tract_flow.datadims, tract_flow.analyzeheader_fa): new edge data: {'connect': [('out_values', 'data_dims')]}
# 190426-17:48:28,839 nipype.workflow DEBUG:
# 	 (tract_flow.fa, tract_flow.niiconv_fa): No edge data
# 190426-17:48:28,840 nipype.workflow DEBUG:
# 	 (tract_flow.fa, tract_flow.niiconv_fa): new edge data: {'connect': [('fa', 'in_file')]}
# 190426-17:48:28,840 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.niiconv_fa): No edge data
# 190426-17:48:28,841 nipype.workflow DEBUG:
# 	 (tract_flow.sf, tract_flow.niiconv_fa): new edge data: {'connect': [('dti_corr', 'header_file')]}
# 190426-17:48:28,841 nipype.workflow DEBUG:
# 	 (tract_flow.niiconv, tract_flow.datasink): Edge data exists: {'connect': [('dt', '3_DTI_QC.@par')]}
# 190426-17:48:28,843 nipype.workflow DEBUG:
# 	 (tract_flow.niiconv, tract_flow.datasink): new edge data: {'connect': [('dt', '3_DTI_QC.@par'), ('dt', '3_Tractography.@par.@par.@par')]}
# 190426-17:48:28,844 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.trace): No edge data
# 190426-17:48:28,844 nipype.workflow DEBUG:
# 	 (tract_flow.dtifit, tract_flow.trace): new edge data: {'connect': [('tensor_fitted', 'in_file')]}
# 190426-17:48:28,845 nipype.workflow DEBUG:
# 	 (tract_flow.trace, tract_flow.analyzeheader_trace): No edge data
# 190426-17:48:28,846 nipype.workflow DEBUG:
# 	 (tract_flow.trace, tract_flow.analyzeheader_trace): new edge data: {'connect': [('trace', 'in_file')]}
# 190426-17:48:28,847 nipype.workflow DEBUG:
# 	 (tract_flow.voxdims, tract_flow.analyzeheader_trace): No edge data
# 190426-17:48:28,848 nipype.workflow DEBUG:
# 	 (tract_flow.voxdims, tract_flow.analyzeheader_trace): new edge data: {'connect': [('out_values', 'voxel_dims')]}
# 190426-17:48:28,849 nipype.workflow DEBUG:
# 	 (tract_flow.datadims, tract_flow.analyzeheader_trace): No edge data
# 190426-17:48:28,850 nipype.workflow DEBUG:
# 	 (tract_flow.datadims, tract_flow.analyzeheader_trace): new edge data: {'connect': [('out_values', 'data_dims')]}
# 190426-17:48:28,850 nipype.workflow DEBUG:
# 	 (tract_flow.trace, tract_flow.trace2nii): No edge data
# 190426-17:48:28,851 nipype.workflow DEBUG:
# 	 (tract_flow.trace, tract_flow.trace2nii): new edge data: {'connect': [('trace', 'data_file')]}
# 190426-17:48:28,852 nipype.workflow DEBUG:
# 	 (tract_flow.getaff, tract_flow.trace2nii): No edge data
# 190426-17:48:28,852 nipype.workflow DEBUG:
# 	 (tract_flow.getaff, tract_flow.trace2nii): new edge data: {'connect': [('out_file', 'affine')]}
# 190426-17:48:28,853 nipype.workflow DEBUG:
# 	 (tract_flow.analyzeheader_trace, tract_flow.trace2nii): No edge data
# 190426-17:48:28,853 nipype.workflow DEBUG:
# 	 (tract_flow.analyzeheader_trace, tract_flow.trace2nii): new edge data: {'connect': [('header', 'header_file')]}
# 190426-17:48:28,854 nipype.workflow DEBUG:
# 	 (tract_flow.trace2nii, tract_flow.datasink): No edge data
# 190426-17:48:28,855 nipype.workflow DEBUG:
# 	 (tract_flow.trace2nii, tract_flow.datasink): new edge data: {'connect': [('nifti_file', '3_Tractography.@par.@par.@par.@par')]}
# 190426-17:48:28,858 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: tract_flow
# 190426-17:48:28,863 nipype.workflow DEBUG:
# 	 expanding workflow: tract_flow
# 190426-17:48:28,864 nipype.workflow DEBUG:
# 	 processing node: tract_flow.infosource
# 190426-17:48:28,865 nipype.workflow DEBUG:
# 	 processing node: tract_flow.sf
# 190426-17:48:28,866 nipype.workflow DEBUG:
# 	 processing node: tract_flow.getaff
# 190426-17:48:28,867 nipype.workflow DEBUG:
# 	 processing node: tract_flow.datadims
# 190426-17:48:28,867 nipype.workflow DEBUG:
# 	 processing node: tract_flow.voxdims
# 190426-17:48:28,869 nipype.workflow DEBUG:
# 	 processing node: tract_flow.image2voxel
# 190426-17:48:28,870 nipype.workflow DEBUG:
# 	 processing node: tract_flow.fsl2scheme
# 190426-17:48:28,870 nipype.workflow DEBUG:
# 	 processing node: tract_flow.dtlutgen
# 190426-17:48:28,871 nipype.workflow DEBUG:
# 	 processing node: tract_flow.dtifit
# 190426-17:48:28,872 nipype.workflow DEBUG:
# 	 processing node: tract_flow.trace
# 190426-17:48:28,873 nipype.workflow DEBUG:
# 	 processing node: tract_flow.analyzeheader_trace
# 190426-17:48:28,873 nipype.workflow DEBUG:
# 	 processing node: tract_flow.trace2nii
# 190426-17:48:28,874 nipype.workflow DEBUG:
# 	 processing node: tract_flow.fa
# 190426-17:48:28,874 nipype.workflow DEBUG:
# 	 processing node: tract_flow.niiconv_fa
# 190426-17:48:28,875 nipype.workflow DEBUG:
# 	 processing node: tract_flow.analyzeheader_fa
# 190426-17:48:28,875 nipype.workflow DEBUG:
# 	 processing node: tract_flow.dteig
# 190426-17:48:28,877 nipype.workflow DEBUG:
# 	 processing node: tract_flow.niiconv
# 190426-17:48:28,878 nipype.workflow DEBUG:
# 	 processing node: tract_flow.picopdfs
# 190426-17:48:28,879 nipype.workflow DEBUG:
# 	 processing node: tract_flow.track
# 190426-17:48:28,879 nipype.workflow DEBUG:
# 	 processing node: tract_flow.datasink
# 190426-17:48:28,880 nipype.workflow DEBUG:
# 	 finished expanding workflow: tract_flow
# 190426-17:48:28,885 nipype.workflow DEBUG:
# 	 using input graph
# 190426-17:48:29,509 nipype.workflow DEBUG:
# 	 creating dot graph
# 190426-17:48:29,928 nipype.workflow INFO:
# 	 Generated workflow graph: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/graph.png (graph2use=flat, simple_form=True).
# 190426-17:48:29,941 nipype.workflow DEBUG:
# 	 [MultiProc] Starting (n_procs=2, mem_gb=28.80, cwd=/Users/myelin/Dropbox/Github/Diffusion)
# 190426-17:48:29,944 nipype.workflow DEBUG:
# 	 Creating flat graph for workflow: tract_flow
# 190426-17:48:29,952 nipype.workflow DEBUG:
# 	 expanding workflow: tract_flow
# 190426-17:48:29,954 nipype.workflow DEBUG:
# 	 processing node: tract_flow.infosource
# 190426-17:48:29,954 nipype.workflow DEBUG:
# 	 processing node: tract_flow.sf
# 190426-17:48:29,955 nipype.workflow DEBUG:
# 	 processing node: tract_flow.getaff
# 190426-17:48:29,956 nipype.workflow DEBUG:
# 	 processing node: tract_flow.datadims
# 190426-17:48:29,956 nipype.workflow DEBUG:
# 	 processing node: tract_flow.voxdims
# 190426-17:48:29,957 nipype.workflow DEBUG:
# 	 processing node: tract_flow.image2voxel
# 190426-17:48:29,958 nipype.workflow DEBUG:
# 	 processing node: tract_flow.fsl2scheme
# 190426-17:48:29,959 nipype.workflow DEBUG:
# 	 processing node: tract_flow.dtlutgen
# 190426-17:48:29,959 nipype.workflow DEBUG:
# 	 processing node: tract_flow.dtifit
# 190426-17:48:29,961 nipype.workflow DEBUG:
# 	 processing node: tract_flow.trace
# 190426-17:48:29,962 nipype.workflow DEBUG:
# 	 processing node: tract_flow.analyzeheader_trace
# 190426-17:48:29,962 nipype.workflow DEBUG:
# 	 processing node: tract_flow.trace2nii
# 190426-17:48:29,963 nipype.workflow DEBUG:
# 	 processing node: tract_flow.fa
# 190426-17:48:29,964 nipype.workflow DEBUG:
# 	 processing node: tract_flow.niiconv_fa
# 190426-17:48:29,965 nipype.workflow DEBUG:
# 	 processing node: tract_flow.analyzeheader_fa
# 190426-17:48:29,966 nipype.workflow DEBUG:
# 	 processing node: tract_flow.dteig
# 190426-17:48:29,967 nipype.workflow DEBUG:
# 	 processing node: tract_flow.niiconv
# 190426-17:48:29,968 nipype.workflow DEBUG:
# 	 processing node: tract_flow.picopdfs
# 190426-17:48:29,969 nipype.workflow DEBUG:
# 	 processing node: tract_flow.track
# 190426-17:48:29,970 nipype.workflow DEBUG:
# 	 processing node: tract_flow.datasink
# 190426-17:48:29,970 nipype.workflow DEBUG:
# 	 finished expanding workflow: tract_flow
# 190426-17:48:29,971 nipype.workflow INFO:
# 	 Workflow tract_flow settings: ['check', 'execution', 'logging', 'monitoring']
# 190426-17:48:29,977 nipype.workflow DEBUG:
# 	 PE: expanding iterables
# 190426-17:48:29,978 nipype.workflow DEBUG:
# 	 Detected iterable nodes [tract_flow.infosource]
# 190426-17:48:29,979 nipype.workflow DEBUG:
# 	 Expanding the iterable node tract_flow.infosource...
# 190426-17:48:29,980 nipype.workflow DEBUG:
# 	 node: tract_flow.infosource iterables: {'subject_id': <function _standardize_iterables.<locals>.make_field_func.<locals>.<lambda> at 0x121af0730>}
# 190426-17:48:29,981 nipype.workflow DEBUG:
# 	 ('subnodes:', [tract_flow.infosource, tract_flow.sf, tract_flow.fsl2scheme, tract_flow.dtifit, tract_flow.datasink, tract_flow.picopdfs, tract_flow.track, tract_flow.dteig, tract_flow.niiconv, tract_flow.fa, tract_flow.analyzeheader_fa, tract_flow.niiconv_fa, tract_flow.trace, tract_flow.analyzeheader_trace, tract_flow.trace2nii, tract_flow.dtlutgen, tract_flow.image2voxel, tract_flow.voxdims, tract_flow.datadims, tract_flow.getaff])
# 190426-17:48:29,988 nipype.workflow DEBUG:
# 	 [Node] infosource - setting input subject_id = 001-prac
# 190426-17:48:29,989 nipype.workflow DEBUG:
# 	 Parameterization: paramstr=_subject_id_001-prac
# 190426-17:48:29,990 nipype.workflow DEBUG:
# 	 PE: expanding iterables ... done
# 190426-17:48:29,991 nipype.workflow DEBUG:
# 	 [Node] sf - setting input subject_id = 001-prac
# 190426-17:48:29,992 nipype.workflow DEBUG:
# 	 Removed the identity node tract_flow.infosource from the graph.
# 190426-17:48:29,998 nipype.workflow DEBUG:
# 	 Performing depth first search
# 190426-17:48:30,3 nipype.workflow INFO:
# 	 Running in parallel.
# 190426-17:48:30,6 nipype.workflow DEBUG:
# 	 Progress: 19 jobs, 0/0/1 (done/running/ready), 0/19 (pending_tasks/waiting).
# 190426-17:48:30,7 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-17:48:30,9 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190426-17:48:30,310 nipype.workflow DEBUG:
# 	 Allocating tract_flow.sf ID=0 (0.20GB, 1 threads). Free: 28.60GB, 1 threads.
# 190426-17:48:30,311 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-17:48:30,313 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data'), ('force_lists', False), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '001-prac')], 65be05be8164d1de39abacfdd6cc1e45, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45.json']
# 190426-17:48:30,313 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "tract_flow.sf".
# 190426-17:48:30,314 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.sf" locally: cached=True, updated=True.
# 190426-17:48:30,325 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task tract_flow.sf (taskid=1).
# 190426-17:48:30,332 nipype.workflow INFO:
# 	 [Node] Setting-up "tract_flow.sf" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf".
# 190426-17:48:30,340 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('base_directory', '/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data'), ('force_lists', False), ('raise_on_empty', True), ('sort_filelist', True), ('subject_id', '001-prac')], 65be05be8164d1de39abacfdd6cc1e45, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45.json']
# 190426-17:48:30,346 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "tract_flow.sf".
# 190426-17:48:30,351 nipype.workflow DEBUG:
# 	 [Node] Rerunning cached, up-to-date node "tract_flow.sf"
# 190426-17:48:30,355 nipype.utils DEBUG:
# 	 Removing contents of /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf
# 190426-17:48:30,360 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_report
# 190426-17:48:30,364 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_report/report.rst"
# 190426-17:48:30,372 nipype.workflow INFO:
# 	 [Node] Running "sf" ("nipype.interfaces.io.SelectFiles")
# 190426-17:48:30,387 nipype.workflow DEBUG:
# 	 Needed files: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/1_Check_Unwarped/_subject_id_001-prac/T1_stripped_anat_mask.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/1_Check_Unwarped/_subject_id_001-prac/T1_stripped_anat.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/t1w.nii.gz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.bval;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.eddy_rotated_bvecs;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_0x65be05be8164d1de39abacfdd6cc1e45_unfinished.json;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_inputs.pklz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_node.pklz
# 190426-17:48:30,392 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_report
# 190426-17:48:30,398 nipype.workflow DEBUG:
# 	 Removing files:
# 190426-17:48:30,407 nipype.workflow DEBUG:
# 	 saved results in /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:30,412 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/_report/report.rst"
# 190426-17:48:30,420 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-17:48:30,425 nipype.workflow INFO:
# 	 [Node] Finished "tract_flow.sf".
# 190426-17:48:32,7 nipype.workflow DEBUG:
# 	 Progress: 19 jobs, 0/1/0 (done/running/ready), 1/18 (pending_tasks/waiting).
# 190426-17:48:32,8 nipype.workflow INFO:
# 	 [Job 0] Completed (tract_flow.sf).
# 190426-17:48:32,11 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-17:48:32,12 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190426-17:48:32,335 nipype.workflow DEBUG:
# 	 Allocating tract_flow.getaff ID=1 (0.20GB, 1 threads). Free: 28.60GB, 1 threads.
# 190426-17:48:32,335 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-17:48:32,336 nipype.workflow DEBUG:
# 	 input: volume
# 190426-17:48:32,337 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:32,338 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:32,340 nipype.workflow DEBUG:
# 	 output: dti_corr
# 190426-17:48:32,340 nipype.workflow DEBUG:
# 	 [Node] getaff - setting input volume = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz
# 190426-17:48:32,342 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('function_str', 'def get_affine(volume):\n    import nibabel as nb\n    from nipype.utils import NUMPY_MMAP\n    nii = nb.load(volume, mmap=NUMPY_MMAP)\n    out_file = nii.affine\n    return out_file\n'), ('volume', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz', '173248d38c8a58f5ba8563e343c0bd3b'))], b9f610319a12ba67c481394ec7253009, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/getaff/_0xb9f610319a12ba67c481394ec7253009.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/getaff/_0xb9f610319a12ba67c481394ec7253009.json']
# 190426-17:48:32,342 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "tract_flow.getaff".
# 190426-17:48:32,343 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.getaff" locally: cached=True, updated=True.
# 190426-17:48:32,344 nipype.workflow DEBUG:
# 	 Skipping cached node tract_flow.getaff with ID 1.
# 190426-17:48:32,345 nipype.workflow INFO:
# 	 [Job 1] Cached (tract_flow.getaff).
# 190426-17:48:32,346 nipype.workflow DEBUG:
# 	 Allocating tract_flow.datadims ID=2 (0.20GB, 1 threads). Free: 28.40GB, 0 threads.
# 190426-17:48:32,347 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-17:48:32,347 nipype.workflow DEBUG:
# 	 input: volume
# 190426-17:48:32,348 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:32,349 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:32,351 nipype.workflow DEBUG:
# 	 output: dti_corr
# 190426-17:48:32,352 nipype.workflow DEBUG:
# 	 [Node] datadims - setting input volume = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz
# 190426-17:48:32,354 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('function_str', 'def get_data_dims(volume):\n    import nibabel as nb\n    from nipype.utils import NUMPY_MMAP\n    if isinstance(volume, list):\n        volume = volume[0]\n    nii = nb.load(volume, mmap=NUMPY_MMAP)\n    hdr = nii.header\n    datadims = hdr.get_data_shape()\n    out_vals = [int(datadims[0]), int(datadims[1]), int(datadims[2])]\n    return out_vals\n'), ('volume', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz', '173248d38c8a58f5ba8563e343c0bd3b'))], 08eddd7ef83b556fab9da7d5e9dbaedc, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/datadims/_0x08eddd7ef83b556fab9da7d5e9dbaedc.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/datadims/_0x08eddd7ef83b556fab9da7d5e9dbaedc.json']
# 190426-17:48:32,354 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "tract_flow.datadims".
# 190426-17:48:32,355 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.datadims" locally: cached=True, updated=True.
# 190426-17:48:32,356 nipype.workflow DEBUG:
# 	 Skipping cached node tract_flow.datadims with ID 2.
# 190426-17:48:32,357 nipype.workflow INFO:
# 	 [Job 2] Cached (tract_flow.datadims).
# 190426-17:48:32,358 nipype.workflow DEBUG:
# 	 Cannot allocate job 3 (0.20GB, 1 threads).
# 190426-17:48:32,360 nipype.workflow DEBUG:
# 	 Cannot allocate job 4 (0.20GB, 1 threads).
# 190426-17:48:32,360 nipype.workflow DEBUG:
# 	 Cannot allocate job 5 (0.20GB, 1 threads).
# 190426-17:48:34,8 nipype.workflow DEBUG:
# 	 Progress: 19 jobs, 3/0/3 (done/running/ready), 0/16 (pending_tasks/waiting).
# 190426-17:48:34,8 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-17:48:34,10 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190426-17:48:34,269 nipype.workflow DEBUG:
# 	 Allocating tract_flow.voxdims ID=3 (0.20GB, 1 threads). Free: 28.60GB, 1 threads.
# 190426-17:48:34,270 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-17:48:34,271 nipype.workflow DEBUG:
# 	 input: volume
# 190426-17:48:34,272 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:34,273 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:34,274 nipype.workflow DEBUG:
# 	 output: dti_corr
# 190426-17:48:34,275 nipype.workflow DEBUG:
# 	 [Node] voxdims - setting input volume = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz
# 190426-17:48:34,276 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('function_str', 'def get_vox_dims(volume):\n    import nibabel as nb\n    from nipype.utils import NUMPY_MMAP\n    if isinstance(volume, list):\n        volume = volume[0]\n    nii = nb.load(volume, mmap=NUMPY_MMAP)\n    hdr = nii.header\n    voxdims = hdr.get_zooms()\n    out_vals = [float(voxdims[0]), float(voxdims[1]), float(voxdims[2])]\n    return out_vals\n'), ('volume', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz', '173248d38c8a58f5ba8563e343c0bd3b'))], 6a63b1fd6533d4dbc1062ca6a094a424, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/voxdims/_0x6a63b1fd6533d4dbc1062ca6a094a424.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/voxdims/_0x6a63b1fd6533d4dbc1062ca6a094a424.json']
# 190426-17:48:34,276 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "tract_flow.voxdims".
# 190426-17:48:34,277 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.voxdims" locally: cached=True, updated=True.
# 190426-17:48:34,278 nipype.workflow DEBUG:
# 	 Skipping cached node tract_flow.voxdims with ID 3.
# 190426-17:48:34,279 nipype.workflow INFO:
# 	 [Job 3] Cached (tract_flow.voxdims).
# 190426-17:48:34,280 nipype.workflow DEBUG:
# 	 Allocating tract_flow.image2voxel ID=4 (0.20GB, 1 threads). Free: 28.40GB, 0 threads.
# 190426-17:48:34,281 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-17:48:34,282 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-17:48:34,283 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:34,283 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:34,285 nipype.workflow DEBUG:
# 	 output: dti_corr
# 190426-17:48:34,286 nipype.workflow DEBUG:
# 	 [Node] image2voxel - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz
# 190426-17:48:34,288 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz', '173248d38c8a58f5ba8563e343c0bd3b')), ('out_type', 'float')], ba78a604cc88dd04f7aed3cb1a0f5cbc, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/_0xba78a604cc88dd04f7aed3cb1a0f5cbc.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/_0xba78a604cc88dd04f7aed3cb1a0f5cbc.json']
# 190426-17:48:34,289 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "tract_flow.image2voxel".
# 190426-17:48:34,290 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.image2voxel" locally: cached=True, updated=True.
# 190426-17:48:34,291 nipype.workflow DEBUG:
# 	 Skipping cached node tract_flow.image2voxel with ID 4.
# 190426-17:48:34,291 nipype.workflow INFO:
# 	 [Job 4] Cached (tract_flow.image2voxel).
# 190426-17:48:34,293 nipype.workflow DEBUG:
# 	 Cannot allocate job 5 (0.20GB, 1 threads).
# 190426-17:48:36,10 nipype.workflow DEBUG:
# 	 Progress: 19 jobs, 5/0/1 (done/running/ready), 0/14 (pending_tasks/waiting).
# 190426-17:48:36,11 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-17:48:36,12 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190426-17:48:36,279 nipype.workflow DEBUG:
# 	 Allocating tract_flow.fsl2scheme ID=5 (0.20GB, 1 threads). Free: 28.60GB, 1 threads.
# 190426-17:48:36,280 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-17:48:36,281 nipype.workflow DEBUG:
# 	 input: bvec_file
# 190426-17:48:36,282 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:36,282 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:36,284 nipype.workflow DEBUG:
# 	 output: bvec
# 190426-17:48:36,285 nipype.workflow DEBUG:
# 	 [Node] fsl2scheme - setting input bvec_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.eddy_rotated_bvecs
# 190426-17:48:36,286 nipype.workflow DEBUG:
# 	 input: bval_file
# 190426-17:48:36,286 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:36,287 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/sf/result_sf.pklz
# 190426-17:48:36,289 nipype.workflow DEBUG:
# 	 output: bval
# 190426-17:48:36,289 nipype.workflow DEBUG:
# 	 [Node] fsl2scheme - setting input bval_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.bval
# 190426-17:48:36,291 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('bval_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/001-prac/dti_pe0.bval', 'd338bc4a17c59573a5aa560ff79bb4c3')), ('bvec_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.eddy_rotated_bvecs', '17fb3c6564026eb17f36bd7b92eb412d')), ('usegradmod', True)], bf238b71e82b40b1a27641101a30ffe1, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/_0xbf238b71e82b40b1a27641101a30ffe1.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/_0xbf238b71e82b40b1a27641101a30ffe1.json']
# 190426-17:48:36,291 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "tract_flow.fsl2scheme".
# 190426-17:48:36,292 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.fsl2scheme" locally: cached=True, updated=True.
# 190426-17:48:36,293 nipype.workflow DEBUG:
# 	 Skipping cached node tract_flow.fsl2scheme with ID 5.
# 190426-17:48:36,293 nipype.workflow INFO:
# 	 [Job 5] Cached (tract_flow.fsl2scheme).
# 190426-17:48:38,12 nipype.workflow DEBUG:
# 	 Progress: 19 jobs, 6/0/2 (done/running/ready), 0/13 (pending_tasks/waiting).
# 190426-17:48:38,12 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-17:48:38,14 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190426-17:48:38,280 nipype.workflow DEBUG:
# 	 Allocating tract_flow.dtlutgen ID=6 (0.20GB, 1 threads). Free: 28.60GB, 1 threads.
# 190426-17:48:38,281 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-17:48:38,282 nipype.workflow DEBUG:
# 	 input: scheme_file
# 190426-17:48:38,282 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/result_fsl2scheme.pklz
# 190426-17:48:38,284 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/result_fsl2scheme.pklz
# 190426-17:48:38,285 nipype.workflow DEBUG:
# 	 output: scheme
# 190426-17:48:38,286 nipype.workflow DEBUG:
# 	 [Node] dtlutgen - setting input scheme_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/eddy_corrected.scheme
# 190426-17:48:38,288 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('inversion', 1), ('scheme_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/eddy_corrected.scheme', 'b6c7e073c7d1866323de653acd9f66f8')), ('snr', '16.0000000000')], 0040e082804938cba8474f7edcc3212b, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtlutgen/_0x0040e082804938cba8474f7edcc3212b.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtlutgen/_0x0040e082804938cba8474f7edcc3212b.json']
# 190426-17:48:38,288 nipype.workflow DEBUG:
# 	 [Node] Up-to-date cache found for "tract_flow.dtlutgen".
# 190426-17:48:38,290 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.dtlutgen" locally: cached=True, updated=True.
# 190426-17:48:38,290 nipype.workflow DEBUG:
# 	 Skipping cached node tract_flow.dtlutgen with ID 6.
# 190426-17:48:38,291 nipype.workflow INFO:
# 	 [Job 6] Cached (tract_flow.dtlutgen).
# 190426-17:48:38,293 nipype.workflow DEBUG:
# 	 Allocating tract_flow.dtifit ID=7 (0.20GB, 1 threads). Free: 28.40GB, 0 threads.
# 190426-17:48:38,293 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-17:48:38,294 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-17:48:38,294 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/result_image2voxel.pklz
# 190426-17:48:38,295 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/result_image2voxel.pklz
# 190426-17:48:38,297 nipype.workflow DEBUG:
# 	 output: voxel_order
# 190426-17:48:38,297 nipype.workflow DEBUG:
# 	 [Node] dtifit - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/eddy_corrected.Bfloat
# 190426-17:48:38,299 nipype.workflow DEBUG:
# 	 input: scheme_file
# 190426-17:48:38,299 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/result_fsl2scheme.pklz
# 190426-17:48:38,300 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/result_fsl2scheme.pklz
# 190426-17:48:38,301 nipype.workflow DEBUG:
# 	 output: scheme
# 190426-17:48:38,301 nipype.workflow DEBUG:
# 	 [Node] dtifit - setting input scheme_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/eddy_corrected.scheme
# 190426-17:48:38,303 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/eddy_corrected.Bfloat', '31ed92be19ddc7aa316682ab0aa3fd72')), ('scheme_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/eddy_corrected.scheme', 'b6c7e073c7d1866323de653acd9f66f8'))], ae4138e787eb70083c43e476078462f7, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/_0xae4138e787eb70083c43e476078462f7.json, []
# 190426-17:48:38,303 nipype.workflow DEBUG:
# 	 [Node] No hashfiles found in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit".
# 190426-17:48:38,305 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.dtifit" locally: cached=False, updated=False.
# 190426-17:48:38,306 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task tract_flow.dtifit (taskid=2).
# 190426-17:48:38,309 nipype.workflow INFO:
# 	 [Node] Setting-up "tract_flow.dtifit" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit".
# 190426-17:48:38,316 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/eddy_corrected.Bfloat', '31ed92be19ddc7aa316682ab0aa3fd72')), ('scheme_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/eddy_corrected.scheme', 'b6c7e073c7d1866323de653acd9f66f8'))], ae4138e787eb70083c43e476078462f7, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/_0xae4138e787eb70083c43e476078462f7.json, []
# 190426-17:48:38,321 nipype.workflow DEBUG:
# 	 [Node] No hashfiles found in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit".
# 190426-17:48:38,326 nipype.utils DEBUG:
# 	 Removing contents of /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit
# 190426-17:48:38,331 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/_report
# 190426-17:48:38,336 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/_report/report.rst"
# 190426-17:48:38,343 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/eddy_corrected.Bfloat
# 190426-17:48:38,349 nipype.interface DEBUG:
# 	 out_file_eddy_corrected_DT.Bdouble
# 190426-17:48:38,354 nipype.interface DEBUG:
# 	 scheme_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/eddy_corrected.scheme
# 190426-17:48:38,359 nipype.workflow INFO:
# 	 [Node] Running "dtifit" ("nipype.interfaces.camino.dti.DTIFit"), a CommandLine Interface with command:
# dtfit /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/eddy_corrected.Bfloat /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/eddy_corrected.scheme > eddy_corrected_DT.Bdouble
# 190426-17:48:38,366 nipype.interface DEBUG:
# 	 in_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/eddy_corrected.Bfloat
# 190426-17:48:38,370 nipype.interface DEBUG:
# 	 out_file_eddy_corrected_DT.Bdouble
# 190426-17:48:38,374 nipype.interface DEBUG:
# 	 scheme_file_/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/eddy_corrected.scheme
# 190426-17:48:40,13 nipype.workflow DEBUG:
# 	 Progress: 19 jobs, 7/1/0 (done/running/ready), 1/11 (pending_tasks/waiting).
# 190426-17:48:40,14 nipype.workflow DEBUG:
# 	 Tasks currently running: 1. Pending: 1.
# 190426-17:48:40,16 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 28.60/28.80, Free processors: 1/2.
#                      Currently running:
#                        * tract_flow.dtifit
# 190426-18:02:17,295 nipype.workflow DEBUG:
# 	 Needed files: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/image2voxel/eddy_corrected.Bfloat;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fsl2scheme/eddy_corrected.scheme;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/_0xae4138e787eb70083c43e476078462f7_unfinished.json;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/command.txt;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/_inputs.pklz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/_node.pklz
# 190426-18:02:17,300 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/_report
# 190426-18:02:17,304 nipype.workflow DEBUG:
# 	 Removing files:
# 190426-18:02:17,309 nipype.workflow DEBUG:
# 	 saved results in /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/result_dtifit.pklz
# 190426-18:02:17,313 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/_report/report.rst"
# 190426-18:02:17,474 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-18:02:17,489 nipype.workflow INFO:
# 	 [Node] Finished "tract_flow.dtifit".
# 190426-18:02:18,802 nipype.workflow INFO:
# 	 [Job 7] Completed (tract_flow.dtifit).
# 190426-18:02:18,804 nipype.workflow DEBUG:
# 	 Tasks currently running: 0. Pending: 0.
# 190426-18:02:18,805 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 28.80/28.80, Free processors: 2/2.
# 190426-18:02:19,63 nipype.workflow DEBUG:
# 	 Allocating tract_flow.trace ID=8 (0.20GB, 1 threads). Free: 28.60GB, 1 threads.
# 190426-18:02:19,64 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-18:02:19,65 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-18:02:19,65 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/result_dtifit.pklz
# 190426-18:02:19,66 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/result_dtifit.pklz
# 190426-18:02:19,69 nipype.workflow DEBUG:
# 	 output: tensor_fitted
# 190426-18:02:19,70 nipype.workflow DEBUG:
# 	 [Node] trace - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble
# 190426-18:02:19,88 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble', '7303ed548a85aeb03034f306cf15ed94'))], 06b211133ab32066249c9a3777016c2c, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/_0x06b211133ab32066249c9a3777016c2c.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/_0x99de62aa8b0dab46135841619367fb80.json']
# 190426-18:02:19,89 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "tract_flow.trace".
# 190426-18:02:19,90 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = 99de62aa8b0dab46135841619367fb80/06b211133ab32066249c9a3777016c2c
# 190426-18:02:19,135 nipype.workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * in_file: ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble', '7303ed548a85aeb03034f306cf15ed94') != ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble', 'f55c53eecf9d7887aed4af31106b64d1']
# 190426-18:02:19,136 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.trace" locally: cached=True, updated=False.
# 190426-18:02:19,137 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task tract_flow.trace (taskid=3).
# 190426-18:02:19,138 nipype.workflow DEBUG:
# 	 Allocating tract_flow.fa ID=11 (0.20GB, 1 threads). Free: 28.40GB, 0 threads.
# 190426-18:02:19,139 nipype.workflow DEBUG:
# 	 Setting node inputs
# 190426-18:02:19,141 nipype.workflow DEBUG:
# 	 input: in_file
# 190426-18:02:19,142 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/result_dtifit.pklz
# 190426-18:02:19,138 nipype.workflow INFO:
# 	 [Node] Setting-up "tract_flow.trace" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace".190426-18:02:19,143 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/result_dtifit.pklz
#
# 190426-18:02:19,146 nipype.workflow DEBUG:
# 	 output: tensor_fitted
# 190426-18:02:19,147 nipype.workflow DEBUG:
# 	 [Node] fa - setting input in_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble
# 190426-18:02:19,146 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble', '7303ed548a85aeb03034f306cf15ed94'))], 06b211133ab32066249c9a3777016c2c, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/_0x06b211133ab32066249c9a3777016c2c.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/_0x99de62aa8b0dab46135841619367fb80.json']
# 190426-18:02:19,150 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "tract_flow.trace".
# 190426-18:02:19,154 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = 99de62aa8b0dab46135841619367fb80/06b211133ab32066249c9a3777016c2c
# 190426-18:02:19,158 nipype.workflow DEBUG:
# 	           Some dictionary entries had differing values:
#             * in_file: ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble', '7303ed548a85aeb03034f306cf15ed94') != ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble', 'f55c53eecf9d7887aed4af31106b64d1']
# 190426-18:02:19,170 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('in_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/dtifit/eddy_corrected_DT.Bdouble', '7303ed548a85aeb03034f306cf15ed94'))], 06b211133ab32066249c9a3777016c2c, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fa/_0x06b211133ab32066249c9a3777016c2c.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fa/_0x99de62aa8b0dab46135841619367fb80.json']
# 190426-18:02:19,170 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "tract_flow.fa".
# 190426-18:02:19,171 nipype.workflow DEBUG:
# ...
# 190426-18:02:29,95 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/result_trace.pklz
# 190426-18:02:29,97 nipype.workflow DEBUG:
# 	 output: trace
# 190426-18:02:29,97 nipype.workflow DEBUG:
# 	 [Node] trace2nii - setting input data_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.img
# 190426-18:02:29,98 nipype.workflow DEBUG:
# 	 input: header_file
# 190426-18:02:29,99 nipype.workflow DEBUG:
# 	 results file: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/analyzeheader_trace/result_analyzeheader_trace.pklz
# 190426-18:02:29,100 nipype.utils DEBUG:
# 	 Loading pkl: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/analyzeheader_trace/result_analyzeheader_trace.pklz
# 190426-18:02:29,102 nipype.workflow DEBUG:
# 	 output: header
# 190426-18:02:29,102 nipype.workflow DEBUG:
# 	 [Node] trace2nii - setting input header_file = /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/analyzeheader_trace/eddy_corrected_DT_TrD.hdr
# 190426-18:02:29,104 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('affine', array([[   1.,    0.,    0., -128.],
#        [   0.,    1.,    0., -128.],
#        [   0.,    0.,    1.,  -99.],
#        [   0.,    0.,    0.,    1.]])), ('data_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.img', '3459eb894c8f2b3ad2209cf859ea83ec')), ('header_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/analyzeheader_trace/eddy_corrected_DT_TrD.hdr', '4eecc3fd833809d785a6ec93c3923594'))], ced7ea092d5a382b1bac620224749c4a, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_0xced7ea092d5a382b1bac620224749c4a.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_0x96d71a8434ee3d27d9c1bd0cab3202fa.json']
# 190426-18:02:29,105 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "tract_flow.trace2nii".
# 190426-18:02:29,106 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = 96d71a8434ee3d27d9c1bd0cab3202fa/ced7ea092d5a382b1bac620224749c4a
# 190426-18:02:29,117 nipype.workflow DEBUG:
# 	 Checking hash "tract_flow.trace2nii" locally: cached=True, updated=False.
# 190426-18:02:29,118 nipype.workflow DEBUG:
# 	 [MultiProc] Submitted task tract_flow.trace2nii (taskid=7).
# 190426-18:02:29,120 nipype.workflow DEBUG:
# 	 Cannot allocate job 13 (0.20GB, 1 threads).
# 190426-18:02:29,120 nipype.workflow DEBUG:
# 	 Cannot allocate job 14 (0.20GB, 1 threads).
# 190426-18:02:29,121 nipype.workflow DEBUG:
# 	 Cannot allocate job 16 (0.20GB, 1 threads).
# 190426-18:02:29,120 nipype.workflow INFO:
# 	 [Node] Setting-up "tract_flow.trace2nii" in "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii".
# 190426-18:02:29,124 nipype.workflow DEBUG:
# 	 [Node] Hashes: [('affine', array([[   1.,    0.,    0., -128.],
#        [   0.,    1.,    0., -128.],
#        [   0.,    0.,    1.,  -99.],
#        [   0.,    0.,    0.,    1.]])), ('data_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.img', '3459eb894c8f2b3ad2209cf859ea83ec')), ('header_file', ('/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/analyzeheader_trace/eddy_corrected_DT_TrD.hdr', '4eecc3fd833809d785a6ec93c3923594'))], ced7ea092d5a382b1bac620224749c4a, /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_0xced7ea092d5a382b1bac620224749c4a.json, ['/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_0x96d71a8434ee3d27d9c1bd0cab3202fa.json']
# 190426-18:02:29,129 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "tract_flow.trace2nii".
# 190426-18:02:29,132 nipype.workflow DEBUG:
# 	 [Node] Old/new hashes = 96d71a8434ee3d27d9c1bd0cab3202fa/ced7ea092d5a382b1bac620224749c4a
# 190426-18:02:29,137 nipype.utils DEBUG:
# 	 Removing contents of /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii
# 190426-18:02:29,157 nipype.workflow DEBUG:
# 	 Unable to write a particular type to the json file
# 190426-18:02:29,162 nipype.utils DEBUG:
# 	 Creating directory /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_report
# 190426-18:02:29,166 nipype.workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_report/report.rst"
# 190426-18:02:29,172 nipype.workflow INFO:
# 	 [Node] Running "trace2nii" ("nipype.algorithms.misc.CreateNifti")
# 190426-18:02:30,693 nipype.workflow DEBUG:
# 	 saved results in /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/niiconv_fa/result_niiconv_fa.pklz
# 190426-18:02:30,698 nipype.workflow WARNING:
# 	 [Node] Error on "tract_flow.niiconv_fa" (/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/niiconv_fa)
# 190426-18:02:30,770 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-18:02:30,811 nipype.workflow DEBUG:
# 	 Progress: 19 jobs, 11/2/3 (done/running/ready), 2/6 (pending_tasks/waiting).
# 190426-18:02:30,812 nipype.workflow DEBUG:
# 	 Clearing 12 from queue
# 190426-18:02:30,992 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-18:02:30,995 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-18:02:30,997 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-18:02:30,999 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-18:02:30,999 nipype.workflow ERROR:
# 	 Node niiconv_fa.a0 failed to run on host myelin.stanford.edu.
# 190426-18:02:31,1 nipype.workflow ERROR:
# 	 Saving crash info to /Users/myelin/Dropbox/Github/Diffusion/crash-20190426-180231-myelin-niiconv_fa.a0-fcd3550c-b5d0-450c-ae0e-cb85d0414b2b.pklz
# Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/multiproc.py", line 69, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 473, in run
#     result = self._run_interface(execute=True)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 557, in _run_interface
#     return self._run_command(execute)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 637, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 375, in run
#     runtime = self._run_interface(runtime)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 758, in _run_interface
#     self.raise_exception(runtime)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 695, in raise_exception
#     ).format(**runtime.dictcopy()))
# RuntimeError: Command:
# dt2nii -inputfile /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fa/eddy_corrected_DT_FA.Bdouble -outputroot eddy_corrected_DT_FA_ -header /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz
# Standard output:
#
# Standard error:
# Apr 26, 2019 6:02:30 PM misc.LoggedException logException
# SEVERE: Exception in thread "main" class data.DataSourceException: No more voxels in data source.
# 	at data.VoxelOrderDataSource.readNextVoxel(VoxelOrderDataSource.java:230)
# 	at data.VoxelOrderDataSource.nextVoxel(VoxelOrderDataSource.java:189)
# 	at apps.DT_ToImage.execute(DT_ToImage.java:98)
# 	at apps.EntryPoint.main(EntryPoint.java:293)
#
# Exception in thread "main" data.DataSourceException: No more voxels in data source.
# 	at data.VoxelOrderDataSource.readNextVoxel(VoxelOrderDataSource.java:230)
# 	at data.VoxelOrderDataSource.nextVoxel(VoxelOrderDataSource.java:189)
# 	at apps.DT_ToImage.execute(DT_ToImage.java:98)
# 	at apps.EntryPoint.main(EntryPoint.java:293)
# Return code: 1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-cbc77b67ac90> in <module>()
#      54 tract_flow.base_dir = workflow_dir
#      55 tract_flow.write_graph(graph2use = 'flat')
# ---> 56 tract = tract_flow.run('MultiProc', plugin_args={'n_procs': 2})
#      57
#      58
#
# /usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     597         if str2bool(self.config['execution']['create_report']):
#     598             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 599         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     600         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     601         if str2bool(self.config['execution']['write_provenance']):
#
# /usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/base.py in run(self, graph, config, updatehash)
#     159                         if result['traceback']:
#     160                             notrun.append(
# --> 161                                 self._clean_queue(jobid, graph, result=result))
#     162                         else:
#     163                             self._task_finished_cb(jobid)
#
# /usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/base.py in _clean_queue(self, jobid, graph, result)
#     222         crashfile = self._report_crash(self.procs[jobid], result=result)
#     223         if str2bool(self._config['execution']['stop_on_first_crash']):
# --> 224             raise RuntimeError("".join(result['traceback']))
#     225         if jobid in self.mapnodesubids:
#     226             # remove current jobid
#
# RuntimeError: Traceback (most recent call last):
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/plugins/multiproc.py", line 69, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 473, in run
#     result = self._run_interface(execute=True)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 557, in _run_interface
#     return self._run_command(execute)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/pipeline/engine/nodes.py", line 637, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 375, in run
#     runtime = self._run_interface(runtime)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 758, in _run_interface
#     self.raise_exception(runtime)
#   File "/usr/local/anaconda3/lib/python3.6/site-packages/nipype/interfaces/base/core.py", line 695, in raise_exception
#     ).format(**runtime.dictcopy()))
# RuntimeError: Command:
# dt2nii -inputfile /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/fa/eddy_corrected_DT_FA.Bdouble -outputroot eddy_corrected_DT_FA_ -header /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/DataDir/2_Eddy_Corrected/_subject_id_001-prac/eddy_corrected.nii.gz
# Standard output:
#
# Standard error:
# Apr 26, 2019 6:02:30 PM misc.LoggedException logException
# SEVERE: Exception in thread "main" class data.DataSourceException: No more voxels in data source.
# 	at data.VoxelOrderDataSource.readNextVoxel(VoxelOrderDataSource.java:230)
# 	at data.VoxelOrderDataSource.nextVoxel(VoxelOrderDataSource.java:189)
# 	at apps.DT_ToImage.execute(DT_ToImage.java:98)
# 	at apps.EntryPoint.main(EntryPoint.java:293)
#
# Exception in thread "main" data.DataSourceException: No more voxels in data source.
# 	at data.VoxelOrderDataSource.readNextVoxel(VoxelOrderDataSource.java:230)
# 	at data.VoxelOrderDataSource.nextVoxel(VoxelOrderDataSource.java:189)
# 	at apps.DT_ToImage.execute(DT_ToImage.java:98)
# 	at apps.EntryPoint.main(EntryPoint.java:293)
# Return code: 1
# 190426-18:02:31,901 nipype.workflow DEBUG:
# 	 Needed files: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/eddy_corrected_DT_TrD.nii;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/eddy_corrected_DT_TrD.mat;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.hdr;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.img;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.mat;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.hdr;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.img;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.mat;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.hdr;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.img;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.mat;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.nii;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace/eddy_corrected_DT_TrD.mat;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/analyzeheader_trace/eddy_corrected_DT_TrD.hdr;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/analyzeheader_trace/eddy_corrected_DT_TrD.img;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/analyzeheader_trace/eddy_corrected_DT_TrD.mat;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_0xced7ea092d5a382b1bac620224749c4a_unfinished.json;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_inputs.pklz;/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_node.pklz
# 190426-18:02:31,905 nipype.workflow DEBUG:
# 	 Needed dirs: /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_report
# 190426-18:02:31,910 nipype.workflow DEBUG:
# 	 Removing files:
# 190426-18:02:31,915 nipype.workflow DEBUG:
# 	 saved results in /Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/result_trace2nii.pklz
# 190426-18:02:31,919 nipype.workflow DEBUG:
# 	 [Node] Writing post-exec report to "/Users/myelin/Dropbox/SNAPLab/Data/ELS_AFQ_prac/dwi_data/workflow/tract_flow/_subject_id_001-prac/trace2nii/_report/report.rst"
# 190426-18:02:32,61 nipype.workflow DEBUG:
# 	 Aggregate: False
# 190426-18:02:32,66 nipype.workflow INFO:
# 	 [Node] Finished "tract_flow.trace2nii".
